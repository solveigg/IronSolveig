# %% [markdown]
# # Using Pandas

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 200)
## to make it possible to display multiple output inside one cell 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# <b>load the data from the vehicles.csv file into pandas data frame

# %%
## Your Code here
mt_cars_full = pd.read_csv("data/vehicles.csv")

# to go up one level '../data/vehicles.csv'

# absolut path == full path from user to file
# relational path == IronSolveig

# %% [markdown]
# First exploration of the dataset:
#
# - How many observations does it have?
# - Look at all the columns: do you understand what they mean?
# - Look at the raw data: do you see anything weird?
# - Look at the data types: are they the expected ones for the information the column contains?

# %%
## Your Code here
mt_cars_full
 #str(mt_cars_full)

mt_cars_full.shape  # equivalent to dim()
mt_cars_full.describe # summary()
mt_cars_full.info #
mt_cars_full.head #head()
mt_cars_full.dtypes  # Almost glimpse!


# 35952 rows × 15 columns
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %% [markdown]
# ### Cleaning and wrangling data
#
# - Some car brand names refer to the same brand. Replace all brand names that contain the word "Dutton" for simply "Dutton". If you find similar examples, clean their names too. Use `loc` with boolean indexing.
#
# - Convert CO2 Emissions from Grams/Mile to Grams/Km
#
# - Create a binary column that solely indicates if the transmission of a car is automatic or manual. Use `pandas.Series.str.startswith` and .
#
# - convert MPG columns to km_per_liter

# %%
## Your Code here

#mt_cars_full[["Make"]]

#mt_cars_full.loc[['Dutton'], ['Make']] 
#mt_cars_full[["Make"]].str.contains(Dutton)

#mt_cars_full[["Make"]].to_string
#mt_cars_full[["Make"]].str.contains("Dutton")



#mt_cars_full.loc[mt_cars_full.str.contains('Dutton'), "Make"] = 'Dutton'## why is this not working?!


mt_cars_full[mt_cars_full["Make"].str.contains("Dutton")]



mt_cars_full.replace({'Make': {11012: "Dutton", 30164: "Dutton", 31754:"Dutton"}})




### Convert CO2 Emissions from Grams/Mile to Grams/Km

mt_cars_full['Emission Grams/Km'] = mt_cars_full['CO2 Emission Grams/Mile']* 0.621373



### Create a binary column that solely indicates if the transmission of a car is automatic or manual. Use pandas.Series.str.startswith and .

mt_cars_full['Manual']= mt_cars_full['Transmission'].str.startswith("M")
# Out:
#                                      Make               Model  Year  \
# 11012                  E. P. Dutton, Inc.       Funeral Coach  1985
# 30164  S and S Coach Company  E.p. Dutton  Funeral Coach  2WD  1984
# 31754    Superior Coaches Div E.p. Dutton  Funeral Coach  2WD  1984
#
#        Engine Displacement  Cylinders     Transmission         Drivetrain  \
# 11012                  4.1        8.0  Automatic 4-spd  Front-Wheel Drive
# 30164                  6.0        8.0  Automatic 3-spd      2-Wheel Drive
# 31754                  6.0        8.0  Automatic 3-spd      2-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 11012     Special Purpose Vehicles   Regular          19.388824        15
# 30164  Special Purpose Vehicle 2WD   Regular          32.961000         9
# 31754  Special Purpose Vehicle 2WD   Regular          32.961000        10
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year  \
# ...

# %% [markdown]
# Converting Grams/Mile to Grams/Km
#
# 1 Mile = 1.60934 Km
#
# Grams/Mile * Mile/Km -> Grams/Mile * 1 Mile/1.60934Km
#
# $$ \frac{Grams}{Mile} * \frac{Mile}{Km} $$
#
# $$ \frac{Grams}{Mile} * \frac{1 Mile}{1.60934Km}  $$

# %% [markdown]
# convert MPG columns to km_per_liter
#
# MPG = Miles/Gallon -> Km/Liter
#
# 1 Mile = 1.60934 Km
#
# 1 Gallon = 3.78541 Liters
#
# $$ \frac{Miles}{Gallon} -> \frac{Miles}{Gallon} * \frac{Km}{Miles} * \frac{Gallon}{Liters}$$
#
# $$ \frac{Miles}{Gallon} -> \frac{Miles}{Gallon} * \frac{1.60934Km}{ 1Miles} * \frac{1 Gallon}{3.78541 Liters}$$
#
# * ( 1.60934 / 3.78541 )

# %% [markdown]
# ### Gathering insights:
#
# - How many car makers are there? How many models? Which car maker has the most cars in the dataset?
#
# - When were these cars made? How big is the engine of these cars?
#
# - What's the frequency of different transmissions, drivetrains and fuel types?
#
# - What's the car that consumes the least/most fuel?

# %%
# Your Code here
mt_cars_full[['Make']].value_counts

print(mt_cars_full['Make'].value_counts())

print(mt_cars_full['Model'].value_counts())
#print(mt_cars_full.nunique(axis=1))

#print(mt_cars_full['Year'].value_counts())


(mt_cars_full['Make']
 .value_counts(sort=True)
 .plot.barh()
 .set_title('#of Cars by Make')
)

# When were these cars made?

(mt_cars_full['Year']
 .value_counts(sort=False)
 .plot.barh()
 .set_title('#of Cars by year')
)
# Out:
# <bound method DataFrame.value_counts of                    Make
# 0            AM General
# 1            AM General
# 2            AM General
# 3            AM General
# 4      ASC Incorporated
# ...                 ...
# 35947             smart
# 35948             smart
# 35949             smart
# 35950             smart
# 35951             smart
#
# [35952 rows x 1 columns]>
# Chevrolet                             3643
# Ford                                  2946
# Dodge                                 2360
# GMC                                   2347
# Toyota                                1836
# BMW                                   1677
# Mercedes-Benz                         1284
# Nissan                                1253
# Volkswagen                            1047
# Mitsubishi                             950
# Mazda                                  915
# Audi                                   890
# Porsche                                862
# ...

# %% [markdown]
# What brand has the worse CO2 Emissions on average?
#
# Hint: use the function `sort_values()`

# %%
## your Code here
#mt_cars_full[["Make"]].groupby.mean(CO2 Emission Grams/Mile)

mt_cars_full['Mean emission'] = mt_cars_full.groupby('Make')["CO2 Emission Grams/Mile"].mean()
mt_cars_full.sort_values('Mean emission', ascending = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [70], in <cell line: 5>()
#       1 ## your Code here
#       2 #mt_cars_full[["Make"]].groupby.mean(CO2 Emission Grams/Mile)
#       4 mt_cars_full['Mean emission'] = mt_cars_full.groupby('Make')["CO2 Emission Grams/Mile"].mean()
# ----> 5 mt_cars_full.sort_values('Mean emission', ascending = TRUE)
#
# NameError: name 'TRUE' is not defined

# %% [markdown]
# Do cars with automatic transmission consume more fuel than cars with manual transmission on average?

# %%
## Your Code is here 
mt_cars_full['Emission by type'] = mt_cars_full.groupby('Manual')["CO2 Emission Grams/Mile"].mean()

mt_cars_full['Emission by type'].head
mt_cars_full['Emission by type'].tail
# Out:
# <bound method NDFrame.head of 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 35947   NaN
# 35948   NaN
# 35949   NaN
# 35950   NaN
# 35951   NaN
# Name: Emission by type, Length: 35952, dtype: float64>
# <bound method NDFrame.tail of 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 35947   NaN
# 35948   NaN
# 35949   NaN
# 35950   NaN
# 35951   NaN
# Name: Emission by type, Length: 35952, dtype: float64>
