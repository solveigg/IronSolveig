# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import quantile_transform
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import OneHotEncoder  ## better to use dummy from pandas 
from sklearn.preprocessing import PowerTransformer
from scipy.stats import boxcox
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from scipy.stats import boxcox
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
pd.options.display.max_rows = 50

# %%
df= pd.read_csv('Data/Data_Marketing_Customer_Analysis_Round3.csv')

# %%
df.drop(["Unnamed: 0"], axis=1,inplace=True)

# %%
numerical = df.select_dtypes(int)

# %%
numerical
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                         4809   48029                    61
# 1                         2228   26794                    64
# 2                        14947   22139                   100
# 3                        22332   49078                    97
# 4                         9025   23675                   117
# ...                        ...     ...                   ...
# 10684                    15563   64811                   253
# 10685                     5259   61146                    65
# 10686                    23893   39837                   201
# 10687                    11971   64195                   158
# 10688                     6857   88784                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                            7                             52
# 1                            3                             26
# 2                           34                             31
# 3                           10                              3
# 4                           15                             31
# ...                        ...                            ...
# 10684                        8                             40
# 10685                        7                             68
# 10686                       11                             63
# 10687                        0                             27
# 10688                       31                              1
#
#        number_of_open_complaints  number_of_policies  total_claim_amount
# 0                              0                   9                 292
# 1                              0                   1                 744
# 2                              0                   2                 480
# 3                              0                   2                 484
# 4                              1                   7                 707
# ...                          ...                 ...                 ...
# 10684                          2                   7                1214
# 10685                          0                   6                 273
# 10686                          0                   2                 381
# 10687                          4                   6                 618
# 10688                          0                   3                1021
#
# [10689 rows x 8 columns]

# %%
categoricals = df.select_dtypes(object)

# %% [markdown]
# ## Activity 6

# %% [markdown]
# ### One Hot/Label Encoding of the categorical variables in the categoricals data frame

# %%
categoricals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10689 entries, 0 to 10688
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   region             10689 non-null  object
#  1   response           10689 non-null  object
#  2   coverage           10689 non-null  object
#  3   education          10689 non-null  object
#  4   effective_to_date  10689 non-null  object
#  5   month              10689 non-null  object
#  6   employment_status  10689 non-null  object
#  7   gender             10689 non-null  object
#  8   location_code      10689 non-null  object
#  9   marital_status     10689 non-null  object
#  10  policy_type        10689 non-null  object
#  11  policy             10689 non-null  object
#  12  renew_offer_type   10689 non-null  object
#  13  sales_channel      10689 non-null  object
#  14  vehicle_class      10689 non-null  object
#  15  vehicle_size       10689 non-null  object
# dtypes: object(16)
# memory usage: 1.3+ MB

# %%
categoricals
# Out:
#             region response  coverage education effective_to_date month  \
# 0          central       no     basic   college           2/18/11   feb
# 1      west region       no     basic   college           1/18/11   jan
# 2             east       no     basic  bachelor           2/10/11   feb
# 3       north west      yes  extended   college           1/11/11   jan
# 4       north west       no   premium  bachelor           1/17/11   jan
# ...            ...      ...       ...       ...               ...   ...
# 10684      central       no   premium  bachelor           1/19/11   jan
# 10685   north west       no     basic   college            1/6/11   jan
# 10686      central       no  extended  bachelor            2/6/11   feb
# 10687  west region       no   premium   college           2/13/11   feb
# 10688  west region       no     basic  bachelor            1/8/11   jan
#
#       employment_status gender location_code marital_status     policy_type  \
# 0              employed      m      suburban        married  corporate auto
# 1            unemployed      f      suburban         single   personal auto
# 2              employed      m      suburban         single   personal auto
# 3              employed      m      suburban         single  corporate auto
# 4         medical leave      f      suburban        married   personal auto
# ...                 ...    ...           ...            ...             ...
# 10684        unemployed      f      suburban        married   personal auto
# 10685          employed      f         urban        married   personal auto
# 10686          employed      f         rural        married  corporate auto
# 10687          employed      f         urban       divorced   personal auto
# 10688        unemployed      m      suburban         single   personal auto
#
#              policy renew_offer_type sales_channel  vehicle_class vehicle_size
# 0      corporate l3           offer3         agent  four-door car      medsize
# 1       personal l3           offer4   call center  four-door car      medsize
# 2       personal l3           offer3   call center            suv      medsize
# 3      corporate l3           offer2        branch  four-door car      medsize
# 4       personal l2           offer1        branch  four-door car      medsize
# ...             ...              ...           ...            ...          ...
# 10684   personal l1           offer3           web     luxury car      medsize
# 10685   personal l3           offer2        branch  four-door car      medsize
# 10686  corporate l3           offer1           web     luxury suv      medsize
# 10687   personal l1           offer1        branch            suv      medsize
# 10688   personal l1           offer4           web            suv      medsize
#
# [10689 rows x 16 columns]

# %%
categoricals.effective_to_date.unique()
# Out:
# array(['2/18/11', '1/18/11', '2/10/11', '1/11/11', '1/17/11', '2/14/11',
#        '2/24/11', '1/19/11', '1/4/11', '1/2/11', '2/7/11', '1/31/11',
#        '1/26/11', '2/28/11', '1/16/11', '2/26/11', '2/23/11', '1/15/11',
#        '2/2/11', '2/15/11', '1/24/11', '2/21/11', '2/22/11', '1/7/11',
#        '1/28/11', '2/8/11', '2/12/11', '2/20/11', '1/5/11', '2/19/11',
#        '1/3/11', '2/3/11', '1/22/11', '1/23/11', '2/5/11', '2/13/11',
#        '1/25/11', '2/16/11', '2/1/11', '1/27/11', '1/12/11', '1/20/11',
#        '2/6/11', '2/11/11', '1/21/11', '1/29/11', '1/9/11', '2/9/11',
#        '2/27/11', '1/1/11', '2/17/11', '2/25/11', '1/13/11', '1/6/11',
#        '2/4/11', '1/14/11', '1/10/11', '1/8/11', '1/30/11'], dtype=object)

# %% [markdown]
# I am going to delete "effective_to_date" because it doesn't make sense to make dummies from every date. In addition we already have a "Month" column.

# %%
categoricals.drop(["effective_to_date"],axis=1,inplace=True)
# Out:
# /home/dani/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# #### Which one are ordinals?
# As we have some columns with an order, we want to change it manually

# %%
categoricals.coverage.unique()
# Out:
# array(['basic', 'extended', 'premium'], dtype=object)

# %%
categoricals["coverage"]  = categoricals["coverage"].replace({'basic': '0', 'extended': '1', 'premium': '2'})
# Out:
# <ipython-input-12-e1d9039445fa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categoricals["coverage"]  = categoricals["coverage"].replace({'basic': '0', 'extended': '1', 'premium': '2'})

# %%
categoricals.education.unique()
# Out:
# array(['college', 'bachelor', 'high school or below', 'doctor', 'master'],
#       dtype=object)

# %%
categoricals["education"]  = categoricals["education"].replace({'high school or below': '0', 'college': '1', 'bachelor': '2', 'master': '3', 'doctor': '4'})
# Out:
# <ipython-input-14-b3e6e3c73703>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categoricals["education"]  = categoricals["education"].replace({'high school or below': '0', 'college': '1', 'bachelor': '2', 'master': '3', 'doctor': '4'})

# %%
categoricals.month.unique()
# Out:
# array(['feb', 'jan'], dtype=object)

# %%
categoricals["month"]  = categoricals["month"].replace({'jan': '0', 'feb': '1'})
# Out:
# <ipython-input-16-817c78909473>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categoricals["month"]  = categoricals["month"].replace({'jan': '0', 'feb': '1'})

# %%
categoricals.vehicle_size.unique()
# Out:
# array(['medsize', 'small', 'large'], dtype=object)

# %%
categoricals["vehicle_size"]  = categoricals["vehicle_size"].replace({'small': '0', 'medsize': '1','large': '2' })
# Out:
# <ipython-input-18-8b0165ea3450>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categoricals["vehicle_size"]  = categoricals["vehicle_size"].replace({'small': '0', 'medsize': '1','large': '2' })

# %% [markdown]
# #### Which one are nominals? GET DUMMIES

# %%
categoricals.policy.unique()
# Out:
# array(['corporate l3', 'personal l3', 'personal l2', 'corporate l2',
#        'personal l1', 'special l1', 'corporate l1', 'special l3',
#        'special l2'], dtype=object)

# %% [markdown]
# We can group all the corporate in a unique value, and the same for personal and corporate

# %%
categoricals.policy = categoricals.policy.apply(lambda x: 'corporate' if 'corporate' in x else x)
categoricals.policy
# Out:
# /home/dani/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 0          corporate
# 1        personal l3
# 2        personal l3
# 3          corporate
# 4        personal l2
#             ...
# 10684    personal l1
# 10685    personal l3
# 10686      corporate
# 10687    personal l1
# 10688    personal l1
# Name: policy, Length: 10689, dtype: object

# %%
categoricals.policy = categoricals.policy.apply(lambda x: 'personal' if 'personal' in x else x)
categoricals.policy = categoricals.policy.apply(lambda x: 'special' if 'special' in x else x)

# %%
categoricals.policy.value_counts()
# Out:
# personal     7937
# corporate    2312
# special       440
# Name: policy, dtype: int64

# %% [markdown]
# - We can also group luxury car and luxury suv

# %%
categoricals.vehicle_class.unique()
# Out:
# array(['four-door car', 'suv', 'two-door car', 'sports car', 'luxury car',
#        'luxury suv'], dtype=object)

# %%
categoricals.vehicle_class = categoricals.vehicle_class.apply(lambda x: 'luxury' if 'luxury' in x else x)
categoricals.vehicle_class.unique()
# Out:
# array(['four-door car', 'suv', 'two-door car', 'sports car', 'luxury'],
#       dtype=object)

# %% [markdown]
# - After get dummies, we would have the policy and policy type columns which would be almost identical. For this reason, we remove policy_type before.

# %%
categoricals.drop(["policy_type"],axis=1,inplace=True)

# %% [markdown]
# <b> Get dummies with drop first

# %% [markdown]
# - Keep in mind that this eliminates one of the categories, for exemple we don't need gender_m and gender_f, just gender_m

# %%
categoricals = pd.get_dummies(data=categoricals, columns=['region', 'response','employment_status','gender','location_code','marital_status','policy','renew_offer_type','sales_channel','vehicle_class'], drop_first=True)

# %%
categoricals.columns
# Out:
# Index(['coverage', 'education', 'month', 'vehicle_size', 'region_east',
#        'region_north west', 'region_west region', 'response_yes',
#        'employment_status_employed', 'employment_status_medical leave',
#        'employment_status_retired', 'employment_status_unemployed', 'gender_m',
#        'location_code_suburban', 'location_code_urban',
#        'marital_status_married', 'marital_status_single', 'policy_personal',
#        'policy_special', 'renew_offer_type_offer2', 'renew_offer_type_offer3',
#        'renew_offer_type_offer4', 'sales_channel_branch',
#        'sales_channel_call center', 'sales_channel_web',
#        'vehicle_class_luxury', 'vehicle_class_sports car', 'vehicle_class_suv',
#        'vehicle_class_two-door car'],
#       dtype='object')

# %% [markdown]
# ### check if there are highly correlated features and drop them if there are any.

# %%
corr = numerical.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(9, 7))
    ax = sns.heatmap(corr, mask=mask,cmap='coolwarm', vmin=-1,vmax=1,annot=True, square=True)

# %% [markdown]
# ### X-y split (y is the target variable which is the total claim amount)

# %%
numerical
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                         4809   48029                    61
# 1                         2228   26794                    64
# 2                        14947   22139                   100
# 3                        22332   49078                    97
# 4                         9025   23675                   117
# ...                        ...     ...                   ...
# 10684                    15563   64811                   253
# 10685                     5259   61146                    65
# 10686                    23893   39837                   201
# 10687                    11971   64195                   158
# 10688                     6857   88784                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                            7                             52
# 1                            3                             26
# 2                           34                             31
# 3                           10                              3
# 4                           15                             31
# ...                        ...                            ...
# 10684                        8                             40
# 10685                        7                             68
# 10686                       11                             63
# 10687                        0                             27
# 10688                       31                              1
#
#        number_of_open_complaints  number_of_policies  total_claim_amount
# 0                              0                   9                 292
# 1                              0                   1                 744
# 2                              0                   2                 480
# 3                              0                   2                 484
# 4                              1                   7                 707
# ...                          ...                 ...                 ...
# 10684                          2                   7                1214
# 10685                          0                   6                 273
# 10686                          0                   2                 381
# 10687                          4                   6                 618
# 10688                          0                   3                1021
#
# [10689 rows x 8 columns]

# %%
df = pd.concat([numerical, categoricals], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10689 entries, 0 to 10688
# Data columns (total 37 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   customer_lifetime_value          10689 non-null  int64
#  1   income                           10689 non-null  int64
#  2   monthly_premium_auto             10689 non-null  int64
#  3   months_since_last_claim          10689 non-null  int64
#  4   months_since_policy_inception    10689 non-null  int64
#  5   number_of_open_complaints        10689 non-null  int64
#  6   number_of_policies               10689 non-null  int64
#  7   total_claim_amount               10689 non-null  int64
#  8   coverage                         10689 non-null  object
#  9   education                        10689 non-null  object
#  10  month                            10689 non-null  object
#  11  vehicle_size                     10689 non-null  object
#  12  region_east                      10689 non-null  uint8
#  13  region_north west                10689 non-null  uint8
#  14  region_west region               10689 non-null  uint8
#  15  response_yes                     10689 non-null  uint8
#  16  employment_status_employed       10689 non-null  uint8
#  17  employment_status_medical leave  10689 non-null  uint8
#  18  employment_status_retired        10689 non-null  uint8
#  19  employment_status_unemployed     10689 non-null  uint8
#  20  gender_m                         10689 non-null  uint8
#  21  location_code_suburban           10689 non-null  uint8
#  22  location_code_urban              10689 non-null  uint8
#  23  marital_status_married           10689 non-null  uint8
#  24  marital_status_single            10689 non-null  uint8
#  25  policy_personal                  10689 non-null  uint8
#  26  policy_special                   10689 non-null  uint8
#  27  renew_offer_type_offer2          10689 non-null  uint8
#  28  renew_offer_type_offer3          10689 non-null  uint8
#  29  renew_offer_type_offer4          10689 non-null  uint8
#  30  sales_channel_branch             10689 non-null  uint8
#  31  sales_channel_call center        10689 non-null  uint8
#  32  sales_channel_web                10689 non-null  uint8
#  33  vehicle_class_luxury             10689 non-null  uint8
#  34  vehicle_class_sports car         10689 non-null  uint8
#  35  vehicle_class_suv                10689 non-null  uint8
#  36  vehicle_class_two-door car       10689 non-null  uint8
# dtypes: int64(8), object(4), uint8(25)
# memory usage: 1.2+ MB

# %%
df["coverage"] = df["coverage"].astype(int)
df["education"] = df["education"].astype(int)
df["month"] = df["month"].astype(int)
df["vehicle_size"] = df["vehicle_size"].astype(int)

# %% [markdown]
# ### REMOVE OUTLIERS

# %% [markdown]
# - Looking for outliers in a boxplot

# %%
plt.boxplot(numerical)
plt.show()

# %% [markdown]
# - Let's take a closer look of some columns

# %%
boxplot_1 = plt.boxplot(numerical['customer_lifetime_value']) #1

# %%
boxplot_3 = plt.boxplot(numerical['monthly_premium_auto']) #3

# %%
boxplot_6 = plt.boxplot(numerical['number_of_open_complaints']) #6

# %%
boxplot_7 = plt.boxplot(numerical['number_of_policies']) #7

# %%
boxplot_8 = plt.boxplot(numerical['total_claim_amount']) #8

# %%
from scipy.stats import scoreatpercentile as pct
from scipy.stats import iqr
def remove_outliers(df):
    pct_75 = pct(df, 75)  # Calculate percentile 75 using scipy function scoreatpercentile
    pct_25 = pct(df, 25)  # Calculate percentile 25 using scipy function scoreatpercentile
    upper_bound = pct_75 + 1.5*iqr(df)  # iqr - > Scipy function to calculate the Interquartile Range
    lower_bound = pct_25 - 1.5*iqr(df)
    df = df[(df <= upper_bound) & (df >= lower_bound)]  # Filter out the outliers
    return df

# %%
df['customer_lifetime_value'] = remove_outliers(df['customer_lifetime_value'])
df['monthly_premium_auto'] = remove_outliers(df['monthly_premium_auto'])
df['total_claim_amount'] = remove_outliers(df['total_claim_amount'])

# %%
len(df)
# Out:
# 10689

# %%
#Remove rows with NaN values after removing outliers

# %%
df = df.dropna()

# %%
len(df)
# Out:
# 9171

# %% [markdown]
# ## Activity 7

# %%
X = df.drop("total_claim_amount", axis=1)
y = df["total_claim_amount"]

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=.30,random_state=123)

# %% [markdown]
# ### ALL THE TRANSFORMATIONS HAS TO BEEN DONE AFTER THE SPLITTING AND APPLIED TO A NEW X_TRAIN CALLED X_TRAIN_SCALED OR X_TRAIN_TRANSFORMATION OR WHATEVER

# %% [markdown]
# <b>First transformation: Standarize the data --> False, we have to do only with numericals!

# %%
std_scaler=StandardScaler().fit(X_train)   ##. finding the parameters ( mean, variance from the training set )

X_train_scaled=std_scaler.transform(X_train)

# %%
X_train_scaled
# Out:
# array([[ 0.38525127,  0.60739036, -1.12553919, ..., -0.22640904,
#         -0.46569522,  1.86364448],
#        [-0.98735573, -1.22149137, -0.2628722 , ..., -0.22640904,
#         -0.46569522, -0.53658303],
#        [-1.12891193, -0.68015066, -0.94392509, ..., -0.22640904,
#         -0.46569522,  1.86364448],
#        ...,
#        [ 1.30520384,  1.16378491,  0.28197011, ..., -0.22640904,
#         -0.46569522,  1.86364448],
#        [ 0.55056287,  0.51113343,  0.46358422, ..., -0.22640904,
#         -0.46569522, -0.53658303],
#        [ 1.56651333,  0.5457015 ,  2.1889182 , ..., -0.22640904,
#          2.14732717, -0.53658303]])

# %%
X_train_scaled.shape
# Out:
# (6419, 36)

# %%
X_test_scaled=std_scaler.transform(X_test)

# %% [markdown]
# <b>Second transformation: Power transformer to get a normal distribution

# %%
#X_train.hist()

# %%
#power=PowerTransformer().fit(X_train_scaled)   ##. finding the parameters ( mean, variance from the training set )

# %%
#power= PowerTransformer()
#power.fit(X_train_scaled)
#X_train_trans = power.transform(X_train_scaled)
#X_test_trans = power.transform(X_test_scaled)

# %%
# We should check is now looks normal distributed

# %% [markdown]
# ### Apply linear regression

# %%
model=LinearRegression()    # model
model.fit(X_train_scaled, y_train)   # model train
# Out:
# LinearRegression()

# %% [markdown]
# <b> model parameters  (b1,b2,b3,b4,b5,b6,b7)

# %%
model.coef_
# Out:
# array([ 2.93629677e-01, -3.03504754e+00,  8.90961942e+01,  1.52018844e-02,
#        -2.19581440e-01, -4.53158590e-01, -1.50316496e-03,  1.60735851e+00,
#        -3.38660579e+00, -4.61996195e-02, -2.85184653e+00,  4.00852924e+00,
#        -1.54733090e+00,  1.76864472e-01, -5.91541122e+00, -2.47211641e+00,
#         9.20249238e-01,  2.07880748e+00,  2.37752988e+01,  3.43521920e+00,
#         1.73020396e+02,  8.13088457e+01, -5.61818567e-01,  1.88587792e+01,
#         7.97732529e-02,  2.00199870e+00,  4.10318098e+00,  1.84288061e+00,
#         3.75510656e+00,  1.31882509e+00, -1.91064717e-01,  1.53944039e+00,
#        -1.07245502e+00,  3.22252624e-02, -5.15423811e-02,  1.16603355e+00])

# %%
model.intercept_
# Out:
# 381.6000934725035

# %% [markdown]
# <b> Making predictions

# %% [markdown]
# We make predictions (y_pred) using X_test_scaled

# %%
y_pred=model.predict(X_test_scaled)   # model prediction

y_pred_train=model.predict(X_train_scaled)

# %%
y_pred.shape
# Out:
# (2752,)

# %%
y_pred_train.shape
# Out:
# (6419,)

# %%
y.shape
# Out:
# (9171,)

# %% [markdown]
# ### Model evaluation

# %%
y_test
# Out:
# 8320     305.0
# 2773       7.0
# 4031      75.0
# 4696     117.0
# 10646     14.0
#          ...
# 10446    547.0
# 3867     806.0
# 9440     547.0
# 7136     246.0
# 9369     491.0
# Name: total_claim_amount, Length: 2752, dtype: float64

# %%
y_pred.shape   #same shape as y_test
# Out:
# (2752,)

# %%
result=pd.DataFrame({"y_test":y_test,"y_pred":y_pred})
result
# Out:
#        y_test      y_pred
# 8320    305.0  246.215498
# 2773      7.0  112.698777
# 4031     75.0  265.483434
# 4696    117.0  163.959193
# 10646    14.0   22.364789
# ...       ...         ...
# 10446   547.0  585.782353
# 3867    806.0  681.706373
# 9440    547.0  576.263719
# 7136    246.0  231.561038
# 9369    491.0  532.137702
#
# [2752 rows x 2 columns]

# %% [markdown]
# ### Analizing the model. What kind of plot you will get if all the all the predictions are ok? A stright line

# %%
# Make an scatter plot y_pred vs y

fig, ax = plt.subplots(1,3,figsize=(14,4))
ax[0].plot(y_pred, y_test, 'o')
ax[0].set_xlabel("y_test")
ax[0].set_ylabel("y_pred")
ax[0].set_title("Test Set - Predicted vs real")

# Get a histogram of the residuals ie: y - y_pred.  Homoscdasticity
# It resembles a normal distribution?
ax[1].hist(y_test - y_pred)
ax[1].set_xlabel("Test y-y_pred")
ax[1].set_title("Test Set Residual histogram")

ax[2].plot(y_pred,y_test - y_pred,"o")
ax[2].set_xlabel("predicted")
ax[2].set_ylabel("residuals")
ax[2].set_title("Residuals by Predicted")
ax[2].plot(y_pred,np.zeros(len(y_pred)),linestyle='dashed')

# %%
# first plot: checking linearity
# second plot: checking normality of residuals. It is a normal distribution, and the majority of residuals are close to 0. good! 
# --> No over or under estimation
# third plot: checking homoscedasticity. Variance is less constant than in the previos model

# %%
sns.regplot(x='y_pred',y='y_test', data=result, scatter_kws={"color": "red"}, line_kws={"color": "black"})
# Out:
# <AxesSubplot:xlabel='y_pred', ylabel='y_test'>

# %% [markdown]
# ### Model evaluation

# %%
print ("MSE is " + str(round(mse(y_test,y_pred),2)))
print ("RMSE is " + str(round(mse(y_test,y_pred,squared=False),2)))
print ("Mean absolute error - MAE - is " + str(round(mae(y_test,y_pred),2)))
# Out:
# MSE is 8900.35
# RMSE is 94.34
# Mean absolute error - MAE - is 71.9

# %% [markdown]
# - r2

# %%
R2 = round(r2_score(y_test,y_pred),4)
R2
# Out:
# 0.7838

# %% [markdown]
# - Adjusted r2

# %%
Adj_R2= round((1 - (1-R2)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)),4)
Adj_R2
# Out:
# 0.7809

# %%
Adj_R2= 1 - (1-(r2_score(y_test,y_pred))*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
Adj_R2
# Out:
# 0.7942285886438613

# %%
Adj_R2 = round(1 - (1-(r2_score(y_test,y_pred))*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)),4)
Adj_R2
# Out:
# 0.7942

# %% [markdown]
# ### Evaluate error metrics also on train test

# %% [markdown]
# - If error_train very high -> Underfitting ( consider other model or to  add more variables)
# - If error_train <= error_test -> Ok
# - If error_train very small and <<<< error_test -> Overfitting!!!! ( you overtrained your model  or you did not applied the transformer to the test set ).

# %%
R2_test=model.score(X_test_scaled,y_test)
R2_train=model.score(X_train_scaled,y_train)

# %%
round(R2_test,4), round(R2_train,4)  #OK
# Out:
# (0.7838, 0.7848)

# %% [markdown]
# ### Feature importance
# - In order to check which independent features are more relevant to your model, compare the absolute value of each coefficient.

# %%
features_importances = pd.DataFrame(data={
    'Attribute': X_train.columns,
    'Importance': abs(model.coef_)
})
features_importances = features_importances.sort_values(by='Importance', ascending=False)

# %%
features_importances
# Out:
#                           Attribute  Importance
# 20           location_code_suburban  173.020396
# 2              monthly_premium_auto   89.096194
# 21              location_code_urban   81.308846
# 18     employment_status_unemployed   23.775299
# 23            marital_status_single   18.858779
# 14                     response_yes    5.915411
# 26          renew_offer_type_offer2    4.103181
# 11                      region_east    4.008529
# 28          renew_offer_type_offer4    3.755107
# 19                         gender_m    3.435219
# 8                         education    3.386606
# 1                            income    3.035048
# 10                     vehicle_size    2.851847
# 15       employment_status_employed    2.472116
# 17        employment_status_retired    2.078807
# 25                   policy_special    2.001999
# 27          renew_offer_type_offer3    1.842881
# 7                          coverage    1.607359
# 12                region_north west    1.547331
# 31                sales_channel_web    1.539440
# 29             sales_channel_branch    1.318825
# 35       vehicle_class_two-door car    1.166034
# 32             vehicle_class_luxury    1.072455
# 16  employment_status_medical leave    0.920249
# 22           marital_status_married    0.561819
# 5         number_of_open_complaints    0.453159
# 0           customer_lifetime_value    0.293630
# 4     months_since_policy_inception    0.219581
# 30        sales_channel_call center    0.191065
# 13               region_west region    0.176864
# 24                  policy_personal    0.079773
# 34                vehicle_class_suv    0.051542
# 9                             month    0.046200
# 33         vehicle_class_sports car    0.032225
# 3           months_since_last_claim    0.015202
# 6                number_of_policies    0.001503

# %%
plt.figure(figsize=(12,12))
plt.bar(x=features_importances['Attribute'], height=features_importances['Importance'], color='#087E8B')
plt.title('Feature importances obtained from coefficients', size=20)
plt.xticks(rotation='vertical')
plt.show()

# %%
numerical.hist(figsize=(12,12))
# Out:
# /home/dani/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# array([[<AxesSubplot:title={'center':'customer_lifetime_value'}>,
#         <AxesSubplot:title={'center':'income'}>,
#         <AxesSubplot:title={'center':'monthly_premium_auto'}>],
#        [<AxesSubplot:title={'center':'months_since_last_claim'}>,
#         <AxesSubplot:title={'center':'months_since_policy_inception'}>,
#         <AxesSubplot:title={'center':'number_of_open_complaints'}>],
#        [<AxesSubplot:title={'center':'number_of_policies'}>,
#         <AxesSubplot:title={'center':'total_claim_amount'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
corr = df.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(9, 7))
    ax = sns.heatmap(corr, mask=mask,cmap='coolwarm', vmin=-1,vmax=1,annot=True, square=True)

# %%
corr = df.corr()
corr
# Out:
#                                  customer_lifetime_value    income  \
# customer_lifetime_value                         1.000000  0.008631
# income                                          0.008631  1.000000
# monthly_premium_auto                            0.421024 -0.000196
# months_since_last_claim                        -0.016327 -0.011455
# months_since_policy_inception                  -0.012386  0.013658
# number_of_open_complaints                      -0.024259  0.008473
# number_of_policies                              0.226531 -0.002897
# total_claim_amount                              0.151703 -0.144381
# coverage                                        0.234234 -0.000836
# education                                      -0.021360  0.016061
# month                                           0.000919 -0.022747
# vehicle_size                                   -0.013479 -0.009413
# region_east                                    -0.020799  0.006486
# region_north west                               0.013175 -0.003042
# region_west region                              0.003354 -0.005878
# response_yes                                    0.017045 -0.059254
# employment_status_employed                      0.065579  0.249695
# employment_status_medical leave                -0.011330 -0.278445
# employment_status_retired                      -0.000018 -0.216340
# employment_status_unemployed                   -0.064248  0.077931
# gender_m                                        0.000303  0.011527
# location_code_suburban                         -0.031234 -0.216390
# location_code_urban                             0.023434  0.121172
# marital_status_married                          0.048156  0.008969
# marital_status_single                          -0.059393  0.027686
# policy_personal                                 0.002085  0.005066
# policy_special                                  0.009337  0.001789
# renew_offer_type_offer2                        -0.081541  0.077662
# renew_offer_type_offer3                        -0.007512  0.003035
# renew_offer_type_offer4                        -0.073021  0.022440
# sales_channel_branch                           -0.001837 -0.010299
# sales_channel_call center                       0.010071  0.020932
# sales_channel_web                              -0.033613  0.013443
# vehicle_class_luxury                           -0.004963 -0.003225
# vehicle_class_sports car                        0.122161 -0.008427
# vehicle_class_suv                               0.267000 -0.001131
# vehicle_class_two-door car                     -0.090280  0.011949
#
#                                  monthly_premium_auto  \
# customer_lifetime_value                      0.421024
# income                                      -0.000196
# monthly_premium_auto                         1.000000
# months_since_last_claim                     -0.008177
# months_since_policy_inception                0.003415
# number_of_open_complaints                   -0.013921
# number_of_policies                          -0.014662
# total_claim_amount                           0.440828
# coverage                                     0.545661
# education                                   -0.020730
# month                                        0.017009
# vehicle_size                                 0.001873
# region_east                                 -0.012270
# region_north west                            0.005640
# region_west region                          -0.002705
# response_yes                                 0.041289
# employment_status_employed                   0.017342
# employment_status_medical leave             -0.005727
# employment_status_retired                    0.011752
# employment_status_unemployed                -0.021509
# gender_m                                    -0.012365
# location_code_suburban                       0.022035
# location_code_urban                         -0.014923
# marital_status_married                       0.047313
# marital_status_single                       -0.049261
# policy_personal                             -0.012067
# policy_special                               0.014506
# renew_offer_type_offer2                     -0.060422
# renew_offer_type_offer3                     -0.011591
# renew_offer_type_offer4                     -0.054456
# sales_channel_branch                         0.016791
# sales_channel_call center                   -0.002757
# sales_channel_web                           -0.031018
# vehicle_class_luxury                        -0.015585
# vehicle_class_sports car                     0.305364
# vehicle_class_suv                            0.620335
# vehicle_class_two-door car                  -0.221141
#
#                                  months_since_last_claim  \
# customer_lifetime_value                        -0.016327
# income                                         -0.011455
# monthly_premium_auto                           -0.008177
# months_since_last_claim                         1.000000
# months_since_policy_inception                  -0.041996
# number_of_open_complaints                       0.001189
# number_of_policies                              0.002760
# total_claim_amount                             -0.020335
# coverage                                       -0.002473
# education                                      -0.000418
# month                                          -0.011552
# vehicle_size                                    0.005690
# region_east                                     0.011354
# region_north west                              -0.011798
# region_west region                             -0.000095
# response_yes                                   -0.020364
# employment_status_employed                     -0.002817
# employment_status_medical leave                 0.019319
# employment_status_retired                      -0.013804
# employment_status_unemployed                   -0.000308
# gender_m                                        0.014934
# location_code_suburban                         -0.018640
# location_code_urban                            -0.006601
# marital_status_married                          0.021960
# marital_status_single                          -0.004174
# policy_personal                                -0.017617
# policy_special                                 -0.003423
# renew_offer_type_offer2                        -0.000995
# renew_offer_type_offer3                        -0.013265
# renew_offer_type_offer4                        -0.007734
# sales_channel_branch                            0.017122
# sales_channel_call center                       0.002724
# sales_channel_web                              -0.023061
# vehicle_class_luxury                            0.019619
# vehicle_class_sports car                        0.000558
# vehicle_class_suv                              -0.008201
# vehicle_class_two-door car                      0.011678
#
#                                  months_since_policy_inception  \
# customer_lifetime_value                              -0.012386
# income                                                0.013658
# monthly_premium_auto                                  0.003415
# months_since_last_claim                              -0.041996
# months_since_policy_inception                         1.000000
# number_of_open_complaints                             0.004564
# number_of_policies                                   -0.013270
# total_claim_amount                                   -0.018909
# coverage                                              0.007663
# education                                             0.018745
# month                                                 0.013044
# vehicle_size                                         -0.002014
# region_east                                           0.019290
# region_north west                                     0.003154
# region_west region                                   -0.016920
# response_yes                                         -0.007132
# employment_status_employed                           -0.021580
# employment_status_medical leave                       0.007496
# employment_status_retired                             0.007788
# employment_status_unemployed                          0.017363
# gender_m                                              0.005077
# location_code_suburban                               -0.022821
# location_code_urban                                   0.022254
# marital_status_married                                0.004124
# marital_status_single                                -0.014246
# policy_personal                                       0.006479
# policy_special                                       -0.019000
# renew_offer_type_offer2                              -0.060855
# renew_offer_type_offer3                               0.005477
# renew_offer_type_offer4                              -0.068836
# sales_channel_branch                                  0.018597
# sales_channel_call center                            -0.027848
# sales_channel_web                                    -0.001624
# vehicle_class_luxury                                 -0.008891
# vehicle_class_sports car                              0.020375
# vehicle_class_suv                                    -0.012281
# vehicle_class_two-door car                           -0.002217
#
#                                  number_of_open_complaints  \
# customer_lifetime_value                          -0.024259
# income                                            0.008473
# monthly_premium_auto                             -0.013921
# months_since_last_claim                           0.001189
# months_since_policy_inception                     0.004564
# number_of_open_complaints                         1.000000
# number_of_policies                                0.002385
# total_claim_amount                               -0.009266
# coverage                                         -0.014268
# education                                         0.008581
# month                                            -0.001087
# vehicle_size                                      0.017256
# region_east                                       0.014994
# region_north west                                -0.011009
# region_west region                               -0.003402
# response_yes                                     -0.003122
# employment_status_employed                        0.003095
# employment_status_medical leave                  -0.008018
# employment_status_retired                         0.011177
# employment_status_unemployed                      0.001986
# gender_m                                         -0.005810
# location_code_suburban                            0.001372
# location_code_urban                               0.000515
# marital_status_married                           -0.002710
# marital_status_single                             0.007873
# policy_personal                                   0.013978
# policy_special                                    0.017459
# renew_offer_type_offer2                          -0.046314
# renew_offer_type_offer3                          -0.008376
# renew_offer_type_offer4                          -0.007439
# sales_channel_branch                             -0.012164
# sales_channel_call center                        -0.008311
# sales_channel_web                                -0.008634
# vehicle_class_luxury                             -0.007868
# vehicle_class_sports car                         -0.006989
# vehicle_class_suv                                -0.012371
# vehicle_class_two-door car                       -0.002470
#
#                                  number_of_policies  total_claim_amount  \
# customer_lifetime_value                    0.226531            0.151703
# income                                    -0.002897           -0.144381
# monthly_premium_auto                      -0.014662            0.440828
# months_since_last_claim                    0.002760           -0.020335
# months_since_policy_inception             -0.013270           -0.018909
# number_of_open_complaints                  0.002385           -0.009266
# number_of_policies                         1.000000           -0.015107
# total_claim_amount                        -0.015107            1.000000
# coverage                                  -0.016635            0.244071
# education                                 -0.012741           -0.141997
# month                                      0.003237            0.011513
# vehicle_size                              -0.022501           -0.102895
# region_east                               -0.013454            0.016365
# region_north west                          0.010793           -0.002877
# region_west region                        -0.001109           -0.001989
# response_yes                              -0.012239            0.043469
# employment_status_employed                 0.006746           -0.375454
# employment_status_medical leave            0.004934            0.045211
# employment_status_retired                 -0.024153            0.078127
# employment_status_unemployed               0.007472            0.347153
# gender_m                                   0.020399            0.058720
# location_code_suburban                    -0.015177            0.686096
# location_code_urban                        0.010662           -0.153975
# marital_status_married                     0.023487           -0.183981
# marital_status_single                     -0.003570            0.243738
# policy_personal                           -0.011499            0.001094
# policy_special                            -0.015410            0.005119
# renew_offer_type_offer2                   -0.046811           -0.055598
# renew_offer_type_offer3                    0.006384           -0.019800
# renew_offer_type_offer4                   -0.080764           -0.039955
# sales_channel_branch                      -0.015952            0.005241
# sales_channel_call center                  0.009185           -0.000124
# sales_channel_web                          0.008708           -0.018048
# vehicle_class_luxury                      -0.005943           -0.002745
# vehicle_class_sports car                   0.012568            0.120520
# vehicle_class_suv                         -0.009273            0.281193
# vehicle_class_two-door car                -0.011268           -0.087608
#
#                                  coverage  education  ...  \
# customer_lifetime_value          0.234234  -0.021360  ...
# income                          -0.000836   0.016061  ...
# monthly_premium_auto             0.545661  -0.020730  ...
# months_since_last_claim         -0.002473  -0.000418  ...
# months_since_policy_inception    0.007663   0.018745  ...
# number_of_open_complaints       -0.014268   0.008581  ...
# number_of_policies              -0.016635  -0.012741  ...
# total_claim_amount               0.244071  -0.141997  ...
# coverage                         1.000000  -0.024376  ...
# education                       -0.024376   1.000000  ...
# month                           -0.012002  -0.012989  ...
# vehicle_size                     0.010230   0.017900  ...
# region_east                      0.000847  -0.008203  ...
# region_north west               -0.006630   0.002299  ...
# region_west region              -0.006272   0.002824  ...
# response_yes                    -0.008012   0.016019  ...
# employment_status_employed       0.015390   0.074767  ...
# employment_status_medical leave -0.004957  -0.014979  ...
# employment_status_retired       -0.005815  -0.034218  ...
# employment_status_unemployed    -0.010067  -0.074365  ...
# gender_m                        -0.012087  -0.006172  ...
# location_code_suburban           0.025844  -0.161293  ...
# location_code_urban             -0.033780   0.096011  ...
# marital_status_married           0.013875   0.030575  ...
# marital_status_single           -0.020770  -0.073470  ...
# policy_personal                  0.003797   0.017673  ...
# policy_special                   0.009330   0.004889  ...
# renew_offer_type_offer2         -0.032993  -0.010198  ...
# renew_offer_type_offer3          0.000662   0.013436  ...
# renew_offer_type_offer4         -0.022078  -0.023966  ...
# sales_channel_branch             0.009410   0.006375  ...
# sales_channel_call center       -0.015035   0.010478  ...
# sales_channel_web               -0.018347  -0.004029  ...
# vehicle_class_luxury            -0.019499   0.019431  ...
# vehicle_class_sports car        -0.019515  -0.009281  ...
# vehicle_class_suv               -0.049484  -0.010199  ...
# vehicle_class_two-door car      -0.001171   0.009566  ...
#
#                                  renew_offer_type_offer2  \
# customer_lifetime_value                        -0.081541
# income                                          0.077662
# monthly_premium_auto                           -0.060422
# months_since_last_claim                        -0.000995
# months_since_policy_inception                  -0.060855
# number_of_open_complaints                      -0.046314
# number_of_policies                             -0.046811
# total_claim_amount                             -0.055598
# coverage                                       -0.032993
# education                                      -0.010198
# month                                          -0.015442
# vehicle_size                                    0.019276
# region_east                                    -0.001449
# region_north west                              -0.003700
# region_west region                              0.000073
# response_yes                                    0.162951
# employment_status_employed                      0.133091
# employment_status_medical leave                -0.031279
# employment_status_retired                      -0.016313
# employment_status_unemployed                   -0.104331
# gender_m                                        0.024530
# location_code_suburban                         -0.039154
# location_code_urban                             0.032525
# marital_status_married                          0.106031
# marital_status_single                          -0.068159
# policy_personal                                 0.010809
# policy_special                                  0.005717
# renew_offer_type_offer2                         1.000000
# renew_offer_type_offer3                        -0.302366
# renew_offer_type_offer4                        -0.248716
# sales_channel_branch                           -0.019455
# sales_channel_call center                       0.059502
# sales_channel_web                               0.054274
# vehicle_class_luxury                            0.002947
# vehicle_class_sports car                       -0.004201
# vehicle_class_suv                              -0.049067
# vehicle_class_two-door car                      0.027836
#
#                                  renew_offer_type_offer3  \
# customer_lifetime_value                        -0.007512
# income                                          0.003035
# monthly_premium_auto                           -0.011591
# months_since_last_claim                        -0.013265
# months_since_policy_inception                   0.005477
# number_of_open_complaints                      -0.008376
# number_of_policies                              0.006384
# total_claim_amount                             -0.019800
# coverage                                        0.000662
# education                                       0.013436
# month                                           0.019364
# vehicle_size                                   -0.000587
# region_east                                    -0.012720
# region_north west                              -0.004852
# region_west region                              0.022052
# response_yes                                   -0.139886
# employment_status_employed                      0.026613
# employment_status_medical leave                -0.016142
# employment_status_retired                      -0.024629
# employment_status_unemployed                   -0.009427
# gender_m                                       -0.002618
# location_code_suburban                         -0.027570
# location_code_urban                             0.017439
# marital_status_married                          0.019161
# marital_status_single                          -0.016068
# policy_personal                                -0.010008
# policy_special                                  0.005314
# renew_offer_type_offer2                        -0.302366
# renew_offer_type_offer3                         1.000000
# renew_offer_type_offer4                        -0.157015
# sales_channel_branch                           -0.006985
# sales_channel_call center                       0.009462
# sales_channel_web                               0.032308
# vehicle_class_luxury                           -0.006553
# vehicle_class_sports car                       -0.017011
# vehicle_class_suv                               0.001566
# vehicle_class_two-door car                     -0.006343
#
#                                  renew_offer_type_offer4  \
# customer_lifetime_value                        -0.073021
# income                                          0.022440
# monthly_premium_auto                           -0.054456
# months_since_last_claim                        -0.007734
# months_since_policy_inception                  -0.068836
# number_of_open_complaints                      -0.007439
# number_of_policies                             -0.080764
# total_claim_amount                             -0.039955
# coverage                                       -0.022078
# education                                      -0.023966
# month                                          -0.007170
# vehicle_size                                   -0.023794
# region_east                                     0.000739
# region_north west                              -0.002801
# region_west region                             -0.004694
# response_yes                                   -0.135985
# employment_status_employed                      0.067130
# employment_status_medical leave                -0.017628
# employment_status_retired                      -0.035910
# employment_status_unemployed                   -0.041689
# gender_m                                        0.041263
# location_code_suburban                         -0.017334
# location_code_urban                            -0.011654
# marital_status_married                          0.069183
# marital_status_single                          -0.049784
# policy_personal                                -0.003180
# policy_special                                  0.002191
# renew_offer_type_offer2                        -0.248716
# renew_offer_type_offer3                        -0.157015
# renew_offer_type_offer4                         1.000000
# sales_channel_branch                           -0.005538
# sales_channel_call center                       0.038157
# sales_channel_web                               0.056281
# vehicle_class_luxury                           -0.012454
# vehicle_class_sports car                       -0.032290
# vehicle_class_suv                              -0.045131
# vehicle_class_two-door car                      0.030897
#
#                                  sales_channel_branch  \
# customer_lifetime_value                     -0.001837
# income                                      -0.010299
# monthly_premium_auto                         0.016791
# months_since_last_claim                      0.017122
# months_since_policy_inception                0.018597
# number_of_open_complaints                   -0.012164
# number_of_policies                          -0.015952
# total_claim_amount                           0.005241
# coverage                                     0.009410
# education                                    0.006375
# month                                       -0.011628
# vehicle_size                                 0.017080
# region_east                                 -0.003965
# region_north west                           -0.010363
# region_west region                           0.008391
# response_yes                                -0.045277
# employment_status_employed                   0.021626
# employment_status_medical leave             -0.004572
# employment_status_retired                   -0.016843
# employment_status_unemployed                -0.012345
# gender_m                                     0.007932
# location_code_suburban                      -0.004952
# location_code_urban                         -0.002542
# marital_status_married                       0.013641
# marital_status_single                       -0.004255
# policy_personal                              0.000270
# policy_special                               0.011587
# renew_offer_type_offer2                     -0.019455
# renew_offer_type_offer3                     -0.006985
# renew_offer_type_offer4                     -0.005538
# sales_channel_branch                         1.000000
# sales_channel_call center                   -0.306987
# sales_channel_web                           -0.260202
# vehicle_class_luxury                        -0.021535
# vehicle_class_sports car                     0.003393
# vehicle_class_suv                            0.008503
# vehicle_class_two-door car                   0.016756
#
#                                  sales_channel_call center  sales_channel_web  \
# customer_lifetime_value                           0.010071          -0.033613
# income                                            0.020932           0.013443
# monthly_premium_auto                             -0.002757          -0.031018
# months_since_last_claim                           0.002724          -0.023061
# months_since_policy_inception                    -0.027848          -0.001624
# number_of_open_complaints                        -0.008311          -0.008634
# number_of_policies                                0.009185           0.008708
# total_claim_amount                               -0.000124          -0.018048
# coverage                                         -0.015035          -0.018347
# education                                         0.010478          -0.004029
# month                                             0.009219          -0.015638
# vehicle_size                                     -0.003349          -0.004899
# region_east                                      -0.008504          -0.007796
# region_north west                                -0.004320           0.024767
# region_west region                                0.000847          -0.014077
# response_yes                                     -0.040161          -0.030109
# employment_status_employed                        0.001746          -0.009086
# employment_status_medical leave                   0.015951           0.012066
# employment_status_retired                        -0.053102           0.018215
# employment_status_unemployed                      0.000406           0.000268
# gender_m                                          0.009728          -0.036641
# location_code_suburban                            0.003443          -0.012736
# location_code_urban                               0.001411           0.006425
# marital_status_married                            0.008196           0.004444
# marital_status_single                            -0.017479          -0.012066
# policy_personal                                   0.004360          -0.001378
# policy_special                                   -0.026125           0.013394
# renew_offer_type_offer2                           0.059502           0.054274
# renew_offer_type_offer3                           0.009462           0.032308
# renew_offer_type_offer4                           0.038157           0.056281
# sales_channel_branch                             -0.306987          -0.260202
# sales_channel_call center                         1.000000          -0.206840
# sales_channel_web                                -0.206840           1.000000
# vehicle_class_luxury                             -0.009185           0.012019
# vehicle_class_sports car                         -0.023073           0.012437
# vehicle_class_suv                                 0.019062          -0.033486
# vehicle_class_two-door car                        0.014017          -0.014925
#
#                                  vehicle_class_luxury  \
# customer_lifetime_value                     -0.004963
# income                                      -0.003225
# monthly_premium_auto                        -0.015585
# months_since_last_claim                      0.019619
# months_since_policy_inception               -0.008891
# number_of_open_complaints                   -0.007868
# number_of_policies                          -0.005943
# total_claim_amount                          -0.002745
# coverage                                    -0.019499
# education                                    0.019431
# month                                       -0.001100
# vehicle_size                                -0.012211
# region_east                                  0.011636
# region_north west                            0.006298
# region_west region                          -0.011747
# response_yes                                -0.004045
# employment_status_employed                  -0.006259
# employment_status_medical leave              0.007294
# employment_status_retired                   -0.006012
# employment_status_unemployed                -0.005116
# gender_m                                    -0.008483
# location_code_suburban                       0.014380
# location_code_urban                          0.000054
# marital_status_married                      -0.003335
# marital_status_single                       -0.006103
# policy_personal                             -0.001220
# policy_special                              -0.007055
# renew_offer_type_offer2                      0.002947
# renew_offer_type_offer3                     -0.006553
# renew_offer_type_offer4                     -0.012454
# sales_channel_branch                        -0.021535
# sales_channel_call center                   -0.009185
# sales_channel_web                            0.012019
# vehicle_class_luxury                         1.000000
# vehicle_class_sports car                    -0.007761
# vehicle_class_suv                           -0.016399
# vehicle_class_two-door car                  -0.018494
#
#                                  vehicle_class_sports car  vehicle_class_suv  \
# customer_lifetime_value                          0.122161           0.267000
# income                                          -0.008427          -0.001131
# monthly_premium_auto                             0.305364           0.620335
# months_since_last_claim                          0.000558          -0.008201
# months_since_policy_inception                    0.020375          -0.012281
# number_of_open_complaints                       -0.006989          -0.012371
# number_of_policies                               0.012568          -0.009273
# total_claim_amount                               0.120520           0.281193
# coverage                                        -0.019515          -0.049484
# education                                       -0.009281          -0.010199
# month                                            0.011234           0.016203
# vehicle_size                                     0.014894          -0.000874
# region_east                                     -0.029298           0.000809
# region_north west                                0.005162           0.006912
# region_west region                              -0.008734          -0.000635
# response_yes                                     0.039467           0.037324
# employment_status_employed                      -0.005357           0.001522
# employment_status_medical leave                  0.001473          -0.006863
# employment_status_retired                        0.012752           0.020033
# employment_status_unemployed                    -0.008863          -0.007654
# gender_m                                         0.007301          -0.004225
# location_code_suburban                           0.004224           0.005035
# location_code_urban                             -0.016427           0.016771
# marital_status_married                           0.012884           0.038105
# marital_status_single                           -0.005169          -0.037692
# policy_personal                                 -0.000337          -0.019479
# policy_special                                   0.004101           0.007526
# renew_offer_type_offer2                         -0.004201          -0.049067
# renew_offer_type_offer3                         -0.017011           0.001566
# renew_offer_type_offer4                         -0.032290          -0.045131
# sales_channel_branch                             0.003393           0.008503
# sales_channel_call center                       -0.023073           0.019062
# sales_channel_web                                0.012437          -0.033486
# vehicle_class_luxury                            -0.007761          -0.016399
# vehicle_class_sports car                         1.000000          -0.105980
# vehicle_class_suv                               -0.105980           1.000000
# vehicle_class_two-door car                      -0.119519          -0.252551
#
#                                  vehicle_class_two-door car
# customer_lifetime_value                           -0.090280
# income                                             0.011949
# monthly_premium_auto                              -0.221141
# months_since_last_claim                            0.011678
# months_since_policy_inception                     -0.002217
# number_of_open_complaints                         -0.002470
# number_of_policies                                -0.011268
# total_claim_amount                                -0.087608
# coverage                                          -0.001171
# education                                          0.009566
# month                                             -0.030144
# vehicle_size                                       0.002459
# region_east                                        0.002681
# region_north west                                  0.016317
# region_west region                                -0.008148
# response_yes                                      -0.013014
# employment_status_employed                        -0.001605
# employment_status_medical leave                    0.009150
# employment_status_retired                         -0.002197
# employment_status_unemployed                      -0.007793
# gender_m                                           0.024678
# location_code_suburban                             0.001004
# location_code_urban                                0.001072
# marital_status_married                            -0.000019
# marital_status_single                              0.023081
# policy_personal                                    0.010903
# policy_special                                    -0.011968
# renew_offer_type_offer2                            0.027836
# renew_offer_type_offer3                           -0.006343
# renew_offer_type_offer4                            0.030897
# sales_channel_branch                               0.016756
# sales_channel_call center                          0.014017
# sales_channel_web                                 -0.014925
# vehicle_class_luxury                              -0.018494
# vehicle_class_sports car                          -0.119519
# vehicle_class_suv                                 -0.252551
# vehicle_class_two-door car                         1.000000
#
# [37 rows x 37 columns]

# %%
df.columns
# Out:
# Index(['customer_lifetime_value', 'income', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'total_claim_amount',
#        'coverage', 'education', 'month', 'vehicle_size', 'region_east',
#        'region_north west', 'region_west region', 'response_yes',
#        'employment_status_employed', 'employment_status_medical leave',
#        'employment_status_retired', 'employment_status_unemployed', 'gender_m',
#        'location_code_suburban', 'location_code_urban',
#        'marital_status_married', 'marital_status_single', 'policy_personal',
#        'policy_special', 'renew_offer_type_offer2', 'renew_offer_type_offer3',
#        'renew_offer_type_offer4', 'sales_channel_branch',
#        'sales_channel_call center', 'sales_channel_web',
#        'vehicle_class_luxury', 'vehicle_class_sports car', 'vehicle_class_suv',
#        'vehicle_class_two-door car'],
#       dtype='object')

# %% [markdown]
# ### Modeling using Statsmodels

# %%
X_train_const_scaled = sm.add_constant(X_train_scaled)
model = sm.OLS(y_train, X_train_const_scaled).fit()
predictions_train = model.predict(X_train_const_scaled)
X_test_const_scaled = sm.add_constant(X_test_scaled)
predictions_test = model.predict(X_test_const_scaled)
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     total_claim_amount   R-squared:                       0.785
# Model:                            OLS   Adj. R-squared:                  0.784
# Method:                 Least Squares   F-statistic:                     646.4
# Date:                Fri, 15 Apr 2022   Prob (F-statistic):               0.00
# Time:                        11:36:28   Log-Likelihood:                -38357.
# No. Observations:                6419   AIC:                         7.679e+04
# Df Residuals:                    6382   BIC:                         7.704e+04
# Df Model:                          36
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        381.6001      1.192    320.038      0.000     379.263     383.938
# x1             0.2936      1.372      0.214      0.831      -2.397       2.984
# x2            -3.0350      1.379     -2.201      0.028      -5.738      -0.332
# x3            89.0962      3.348     26.613      0.000      82.533      95.659
# x4             0.0152      1.199      0.013      0.990      -2.334       2.365
# x5            -0.2196      1.207     -0.182      0.856      -2.586       2.147
# x6            -0.4532      1.199     -0.378      0.705      -2.803       1.897
# x7            -0.0015      1.246     -0.001      0.999      -2.443       2.440
# x8             1.6074      2.276      0.706      0.480      -2.855       6.069
# x9            -3.3866      1.217     -2.783      0.005      -5.772      -1.001
# x10           -0.0462      1.198     -0.039      0.969      -2.395       2.302
# x11           -2.8518      1.213     -2.351      0.019      -5.229      -0.474
# x12            4.0085      1.304      3.075      0.002       1.453       6.564
# x13           -1.5473      1.430     -1.082      0.279      -4.350       1.256
# x14            0.1769      1.439      0.123      0.902      -2.645       2.999
# x15           -5.9154      1.297     -4.560      0.000      -8.459      -3.372
# x16           -2.4721      3.041     -0.813      0.416      -8.433       3.489
# x17            0.9202      1.680      0.548      0.584      -2.372       4.213
# x18            2.0788      1.572      1.322      0.186      -1.003       5.161
# x19           23.7753      2.883      8.247      0.000      18.124      29.427
# x20            3.4352      1.204      2.853      0.004       1.074       5.796
# x21          173.0204      1.654    104.583      0.000     169.777     176.264
# x22           81.3088      1.490     54.563      0.000      78.388      84.230
# x23           -0.5618      1.740     -0.323      0.747      -3.973       2.849
# x24           18.8588      1.798     10.488      0.000      15.334      22.384
# x25            0.0798      1.276      0.063      0.950      -2.421       2.581
# x26            2.0020      1.276      1.569      0.117      -0.499       4.503
# x27            4.1032      1.398      2.935      0.003       1.363       6.843
# x28            1.8429      1.321      1.395      0.163      -0.748       4.433
# x29            3.7551      1.333      2.817      0.005       1.142       6.369
# x30            1.3188      1.340      0.984      0.325      -1.309       3.946
# x31           -0.1911      1.337     -0.143      0.886      -2.813       2.430
# x32            1.5394      1.316      1.169      0.242      -1.041       4.120
# x33           -1.0725      1.196     -0.897      0.370      -3.417       1.272
# x34            0.0322      1.775      0.018      0.986      -3.448       3.512
# x35           -0.0515      2.588     -0.020      0.984      -5.124       5.021
# x36            1.1660      1.252      0.932      0.352      -1.288       3.620
# ==============================================================================
# Omnibus:                      823.894   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1443.756
# Skew:                           0.854   Prob(JB):                         0.00
# Kurtosis:                       4.575   Cond. No.                         6.78
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# P-value technique: variable with p value less than 0.05 effects the result. We could remove the other ones. (null hyphotessi: this column no affect)
# smaler than 0.05 is on the rejected zone
