# %%
# The new Foreign Minister of Germany announced Germany will follow a 'Ferminist Foreign Policy'
# (FFP) approach. It remained largely open what FFP meant. The coalition agreement and subesequent documents 
# refered to equal access to opportunities, education,jobs, represntation of women in senior positions, 
# reproductive choice. 
# If AB would walk the talk, whow would that alter the map of partners?
# To apply the skills accquired at IH, the project combines some traditional developmenyt indicators with those
# mentioned above to come up with clusters of countries sharing development and gedern
# dynamics

# %%
import numpy as np
import pandas as pd
from functools import reduce
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as plt

import researchpy as rp # t-test - 3. 
from scipy.stats import ttest_ind # independece of sex disaggregated vars 3.

from sklearn.preprocessing import StandardScaler # scaling 4. 

from sklearn.cluster import KMeans  # chap 5
from sklearn.metrics import silhouette_score
from yellowbrick.cluster import SilhouetteVisualizer


from sklearn.decomposition import PCA # rund PCA 6

# %%
eco = pd.read_csv('econ_gdp.csv')
gen = pd.read_csv('gender.csv')
fert = pd.read_csv('fertility.csv')
br = pd.read_csv('birthRegistry.csv')
sdg = pd.read_csv('sdg.csv')
le_tot = pd.read_csv('life_ex_tot.csv')
poverty = pd.read_csv('poverty_190.csv')
literacy = pd.read_csv('literacyrate.csv')

## All indiactors can be found in the WB data base

# %%
df = pd.read_csv('220516_compiled_data.csv') ## compiled df, used from 4. onwards

# %% [markdown]
# # Uniforming and joining data

# %%
## Birth registry 

br['br'] = br.mean(axis=1)

br.drop(br.iloc[:, 1:14], inplace = True, axis = 1) # drop not used cols

#br = br.iloc[:, 0:]
# Out:
# /var/folders/np/_4nsf5195pl0jfyhg25kr9q80000gn/T/ipykernel_10252/429864583.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   br['br'] = br.mean(axis=1)

# %%
br
# Out:
#                          country         br
# 0                          Aruba        NaN
# 1    Africa Eastern and Southern  36.951135
# 2                    Afghanistan  42.300000
# 3     Africa Western and Central  55.179299
# 4                         Angola  25.000000
# ..                           ...        ...
# 261                       Kosovo        NaN
# 262                  Yemen, Rep.  23.900000
# 263                 South Africa  87.000000
# 264                       Zambia  12.700000
# 265                     Zimbabwe  40.625000
#
# [266 rows x 2 columns]

# %%
sdg
# Out:
#                                                country water_perc sani_perc  \
# 0                                          Afghanistan       27.6        ..
# 1                                              Albania       70.7      47.7
# 2                                              Algeria       72.4      17.6
# 3                                       American Samoa       98.4        ..
# 4                                              Andorra       90.6       100
# ..                                                 ...        ...       ...
# 329                                   General comments        NaN       NaN
# 330  Please cite the International Telecommunicatio...        NaN       NaN
# 331                                                NaN        NaN       NaN
# 332                                                NaN        NaN       NaN
# 333  Please see the online table at http://wdi.worl...        NaN       NaN
#
#     elec_perc slum_perc homocides Internetuse
# 0        97.7      62.7       9.8         8.3
# 1        99.9        ..       2.2        62.4
# 2        99.6        ..       1.4        47.7
# 3          ..        ..       7.2          ..
# 4         100        ..         0        91.6
# ..        ...       ...       ...         ...
# 329       NaN       NaN       NaN         NaN
# 330       NaN       NaN       NaN         NaN
# 331       NaN       NaN       NaN         NaN
# 332       NaN       NaN       NaN         NaN
# 333       NaN       NaN       NaN         NaN
#
# [334 rows x 7 columns]

# %%
#fertility 


fert['fert'] = fert.mean(axis=1) # average of last xx years
fert = fert[['country', 'fert']]
#fert.drop(fert.iloc[:, 1:11], inplace = True, axis = 1) # drop not used cols

fert
# Out:
# /var/folders/np/_4nsf5195pl0jfyhg25kr9q80000gn/T/ipykernel_10252/1954580804.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   fert['fert'] = fert.mean(axis=1) # average of last xx years
#                          country      fert
# 0                          Aruba  1.877714
# 1    Africa Eastern and Southern  4.498405
# 2                    Afghanistan  4.648857
# 3     Africa Western and Central  5.181653
# 4                         Angola  5.608000
# ..                           ...       ...
# 261                       Kosovo  2.031429
# 262                  Yemen, Rep.  3.901000
# 263                 South Africa  2.432286
# 264                       Zambia  4.737714
# 265                     Zimbabwe  3.712429
#
# [266 rows x 2 columns]

# %%
#literacy rate 


literacy['literacy'] = literacy.mean(axis=1)  # average of last 10 yeras
literacy= literacy[['country', 'literacy']]


literacy
# Out:
# /var/folders/np/_4nsf5195pl0jfyhg25kr9q80000gn/T/ipykernel_10252/2128451589.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   literacy['literacy'] = literacy.mean(axis=1)  # average of last 10 yeras
#                          country   literacy
# 0                          Aruba  97.807419
# 1    Africa Eastern and Southern        NaN
# 2                    Afghanistan  34.357446
# 3     Africa Western and Central        NaN
# 4                         Angola  66.030113
# ..                           ...        ...
# 261                       Kosovo        NaN
# 262                  Yemen, Rep.        NaN
# 263                 South Africa  92.901512
# 264                       Zambia  86.747963
# 265                     Zimbabwe  86.138065
#
# [266 rows x 2 columns]

# %%
# poverty 


poverty['pov'] = poverty.mean(axis=1)  # average of last 10 yeras
poverty= poverty[['country', 'pov']]


poverty
# Out:
# /var/folders/np/_4nsf5195pl0jfyhg25kr9q80000gn/T/ipykernel_10252/3475801980.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   poverty['pov'] = poverty.mean(axis=1)  # average of last 10 yeras
#                          country        pov
# 0                          Aruba        NaN
# 1    Africa Eastern and Southern        NaN
# 2                    Afghanistan        NaN
# 3     Africa Western and Central        NaN
# 4                         Angola  49.900000
# ..                           ...        ...
# 261                       Kosovo   0.785714
# 262                  Yemen, Rep.  18.300000
# 263                 South Africa  18.700000
# 264                       Zambia  58.700000
# 265                     Zimbabwe  31.600000
#
# [266 rows x 2 columns]

# %%
# Life expectancy at birth


le_tot['lifeEx'] = le_tot.mean(axis=1)  # average of last 10 yeras
le_tot= le_tot[['country', 'lifeEx']]
# Out:
# /var/folders/np/_4nsf5195pl0jfyhg25kr9q80000gn/T/ipykernel_10252/4087952758.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   le_tot['lifeEx'] = le_tot.mean(axis=1)  # average of last 10 yeras

# %%
#le_tot

# %% [markdown]
# ### Join

# %%
df = [eco, gen, fert, br,sdg, poverty, literacy, le_tot] # compile all data in one list

# %%
# Merge all data

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['country'],
                                            how='inner'), df)

# %%
df_merged.columns # Check 
#df_merged.info
# Out:
# Index(['country', 'Population', 'pop_density', 'gni', 'gni_pc', 'ppp_gni',
#        'ppp_gni.1', 'gdp', 'gdp_pc', 'lifeEx_m', 'lifeEx_f', 'married_by_18',
#        'mobile_money_m', 'mobile_money_m.1', 'employment_m', 'eomployment_f',
#        'firm_f_ownership', 'share_senior_f', 'parlia_w', 'fert', 'br',
#        'water_perc', 'sani_perc', 'elec_perc', 'slum_perc', 'homocides',
#        'Internetuse', 'pov', 'literacy', 'lifeEx'],
#       dtype='object')

# %%
# rename columns

df_merged.rename(columns={'ppp_gni.1': 'ppp_gni.pc',
                   'eomployment_f': 'employment_f', 
                  'mobile_money_m.1': 'mobile_money_f'},
          inplace=True, errors='raise')

# %% [markdown]
# # Familizarize with data

# %%
df_merged.tail(20)
# Out:
#                         country Population pop_density        gni  gni_pc  \
# 205                     Vanuatu        0.3          24          1   3,210
# 206               Venezuela, RB       28.5          33         ..      ..
# 207                     Vietnam       96.5         308      249.4   2,590
# 208       Virgin Islands (U.S.)        0.1         306         ..      ..
# 209          West Bank and Gaza        4.7         759       19.1   4,190
# 210                 Yemen, Rep.       29.2          54       26.7     940
# 211                      Zambia       17.9          23       25.6   1,430
# 212                    Zimbabwe       14.6          37       20.4   1,390
# 213                       World   7,673.50          58  88,792.20  11,571
# 214         East Asia & Pacific   2,340.60          95  27,464.90  11,734
# 215       Europe & Central Asia      921.1          33  23,217.20  25,205
# 216   Latin America & Caribbean      646.4          32   5,684.80   8,794
# 217  Middle East & North Africa      456.7          40   3,598.90   7,880
# 218               North America      365.9          20  23,366.20  63,861
# 219                  South Asia   1,835.80         380   3,660.20   1,994
# 220          Sub-Saharan Africa   1,107.00          45   1,720.80   1,555
# 221                  Low income      668.5          43      547.9     820
# 222         Lower middle income   2,913.40         131   6,340.10   2,176
# 223         Upper middle income   2,855.90          49  25,884.40   9,064
# 224                 High income   1,235.90          35  56,050.30  45,354
#
#         ppp_gni ppp_gni.pc   gdp gdp_pc lifeEx_m  ...          br water_perc  \
# 205           1      3,320   3.3    0.8     69.1  ...   43.400000         ..
# 206          ..         ..    ..     ..     68.3  ...   81.000000         ..
# 207         763      7,910     7      6     71.4  ...   96.100000         ..
# 208          ..         ..  -1.7   -1.5     76.6  ...         NaN       97.9
# 209        35.2      7,510   0.9   -1.6     72.6  ...   98.133333       79.7
# 210          ..         ..   2.1   -0.2     64.5  ...   23.900000         ..
# 211        63.6      3,560   1.4   -1.5     61.1  ...   12.700000         ..
# 212        40.1      2,740  -8.1   -9.4       60  ...   40.625000       29.5
# 213  136,001.00     17,723   2.4    1.3     70.6  ...   71.076035       74.3
# 214   43,339.80     18,516   3.8    3.2       74  ...         NaN         ..
# 215   34,570.30     37,530   1.5    1.2     74.3  ...   99.593697       91.7
# 216   10,645.00     16,467   0.9   -0.1     72.6  ...   94.635445       75.4
# 217    7,742.50     16,953   0.5   -1.2     72.8  ...         NaN       78.5
# 218   23,617.80     64,548   2.1    1.5       75  ...  100.000000       97.3
# 219   11,837.30      6,448   4.1    2.9     68.6  ...   69.973045         ..
# 220    4,207.00      3,801   2.3   -0.4     60.2  ...   44.909449       30.2
# 221    1,637.70      2,450     4    1.3     62.2  ...   40.558623       28.6
# 222   19,697.90      6,761     4    2.5     67.6  ...   67.109327         60
# 223   49,338.80     17,276   3.6    2.9     73.4  ...         NaN       75.6
# 224   65,588.50     53,071   1.6    1.2     77.7  ...   99.957666       97.7
#
#     sani_perc elec_perc slum_perc homocides Internetuse        pov   literacy  \
# 205        ..      62.8        ..        ..        25.7   8.600000  86.103153
# 206      23.1      99.2        32        52          57        NaN  96.167508
# 207        ..       100      27.2        ..        58.1   2.225000  95.753868
# 208        ..       100        ..      49.3        64.4        NaN        NaN
# 209      66.7      99.7        ..       1.2        63.3   0.500000  96.518783
# 210      18.8      79.2      60.8       6.8        26.7  18.300000        NaN
# 211        ..      40.3        54       5.4          ..  58.700000  86.747963
# 212      25.7      40.1      25.1       7.5        24.4  31.600000  86.138065
# 213        54      88.6      29.6       5.3        46.3  10.725000  85.646122
# 214      60.1      97.8      25.8       1.4        54.7   3.144444  95.093091
# 215      69.8       100        ..       3.3        74.5   1.500000  98.190924
# 216      34.1      97.7      21.1      22.3        62.7   4.300000  93.320525
# 217      38.8      97.7        ..       3.4        56.9   4.037500  79.735232
# 218      81.1       100        ..       4.6        87.8        NaN        NaN
# 219      44.8      89.7      30.5       3.6        17.1  18.000000  70.173038
# 220      21.3      43.4      55.3       9.4        22.3  41.300000  63.569308
# 221      17.6      38.4      68.2       7.3        14.1  46.512500  58.923505
# 222      45.7      85.7      32.2       4.5        25.7  15.025000  73.815040
# 223      57.8      99.3      23.2       6.7        58.8   2.566667  95.254961
# 224        87       100        ..       2.2        85.9   0.600000        NaN
#
#         lifeEx
# 205  70.322600
# 206  72.181800
# 207  75.324600
# 208  79.508780
# 209  73.898000
# 210  66.115000
# 211  63.419400
# 212  61.105800
# 213  72.532291
# 214  76.057405
# 215  77.768885
# 216  75.441776
# 217  74.083606
# 218  78.721549
# 219  69.402244
# 220  61.234800
# 221  63.368600
# 222  68.853723
# 223  75.694861
# 224  80.679517
#
# [20 rows x 30 columns]

# %%
df_merged.shape
# Out:
# (225, 30)

# %% [markdown]
# ## Seperate groups and countries

# %%
country = df_merged['country'] # Seperate country to be able to change type

# %%
df_merged.drop('country', axis=1, inplace=True)

# %%
df_merged
# Out:
#     Population pop_density        gni  gni_pc    ppp_gni ppp_gni.pc  gdp  \
# 0           38          57         20     530       83.3      2,190  3.9
# 1          2.9         105       14.9   5,220       41.3     14,450  2.2
# 2         43.1          18      172.5   4,010      504.8     11,720  0.8
# 3          0.1         277         ..      ..         ..         ..  2.2
# 4          0.1         164         ..      ..         ..         ..  1.8
# ..         ...         ...        ...     ...        ...        ...  ...
# 220   1,107.00          45   1,720.80   1,555   4,207.00      3,801  2.3
# 221      668.5          43      547.9     820   1,637.70      2,450    4
# 222   2,913.40         131   6,340.10   2,176  19,697.90      6,761    4
# 223   2,855.90          49  25,884.40   9,064  49,338.80     17,276  3.6
# 224   1,235.90          35  56,050.30  45,354  65,588.50     53,071  1.6
#
#     gdp_pc lifeEx_m lifeEx_f  ...          br water_perc sani_perc elec_perc  \
# 0      1.5     63.7     66.7  ...   42.300000       27.6        ..      97.7
# 1      2.7     77.2     80.3  ...   98.400000       70.7      47.7      99.9
# 2     -1.1     75.9     78.3  ...   99.600000       72.4      17.6      99.6
# 3      2.5       ..       ..  ...         NaN       98.4        ..        ..
# 4      1.7       ..       ..  ...  100.000000       90.6       100       100
# ..     ...      ...      ...  ...         ...        ...       ...       ...
# 220   -0.4     60.2     63.7  ...   44.909449       30.2      21.3      43.4
# 221    1.3     62.2       66  ...   40.558623       28.6      17.6      38.4
# 222    2.5     67.6     71.1  ...   67.109327         60      45.7      85.7
# 223    2.9     73.4     78.7  ...         NaN       75.6      57.8      99.3
# 224    1.2     77.7     83.1  ...   99.957666       97.7        87       100
#
#     slum_perc homocides Internetuse        pov   literacy     lifeEx
# 0        62.7       9.8         8.3        NaN  34.357446  64.477000
# 1          ..       2.2        62.4   0.500000  97.411140  78.448800
# 2          ..       1.4        47.7   0.400000  81.407837  76.686600
# 3          ..       7.2          ..        NaN        NaN        NaN
# 4          ..         0        91.6        NaN        NaN        NaN
# ..        ...       ...         ...        ...        ...        ...
# 220      55.3       9.4        22.3  41.300000  63.569308  61.234800
# 221      68.2       7.3        14.1  46.512500  58.923505  63.368600
# 222      32.2       4.5        25.7  15.025000  73.815040  68.853723
# 223      23.2       6.7        58.8   2.566667  95.254961  75.694861
# 224        ..       2.2        85.9   0.600000        NaN  80.679517
#
# [225 rows x 29 columns]

# %%
df_merged = df_merged.apply(pd.to_numeric, errors= 'coerce') # chnage type

# %%
df_merged.dtypes
# Out:
# Population          float64
# pop_density         float64
# gni                 float64
# gni_pc              float64
# ppp_gni             float64
# ppp_gni.pc          float64
# gdp                 float64
# gdp_pc              float64
# lifeEx_m            float64
# lifeEx_f            float64
# married_by_18       float64
# mobile_money_m      float64
# mobile_money_f      float64
# employment_m        float64
# employment_f        float64
# firm_f_ownership    float64
# share_senior_f      float64
# parlia_w            float64
# fert                float64
# br                  float64
# water_perc          float64
# sani_perc           float64
# elec_perc           float64
# slum_perc           float64
# homocides           float64
# Internetuse         float64
# pov                 float64
# literacy            float64
# lifeEx              float64
# dtype: object

# %%
df_merged['country'] = country  # add country col back

# %%
df_merged
# Out:
#      Population  pop_density    gni  gni_pc  ppp_gni  ppp_gni.pc  gdp  gdp_pc  \
# 0          38.0         57.0   20.0   530.0     83.3         NaN  3.9     1.5
# 1           2.9        105.0   14.9     NaN     41.3         NaN  2.2     2.7
# 2          43.1         18.0  172.5     NaN    504.8         NaN  0.8    -1.1
# 3           0.1        277.0    NaN     NaN      NaN         NaN  2.2     2.5
# 4           0.1        164.0    NaN     NaN      NaN         NaN  1.8     1.7
# ..          ...          ...    ...     ...      ...         ...  ...     ...
# 220         NaN         45.0    NaN     NaN      NaN         NaN  2.3    -0.4
# 221       668.5         43.0  547.9   820.0      NaN         NaN  4.0     1.3
# 222         NaN        131.0    NaN     NaN      NaN         NaN  4.0     2.5
# 223         NaN         49.0    NaN     NaN      NaN         NaN  3.6     2.9
# 224         NaN         35.0    NaN     NaN      NaN         NaN  1.6     1.2
#
#      lifeEx_m  lifeEx_f  ...  water_perc  sani_perc  elec_perc  slum_perc  \
# 0        63.7      66.7  ...        27.6        NaN       97.7       62.7
# 1        77.2      80.3  ...        70.7       47.7       99.9        NaN
# 2        75.9      78.3  ...        72.4       17.6       99.6        NaN
# 3         NaN       NaN  ...        98.4        NaN        NaN        NaN
# 4         NaN       NaN  ...        90.6      100.0      100.0        NaN
# ..        ...       ...  ...         ...        ...        ...        ...
# 220      60.2      63.7  ...        30.2       21.3       43.4       55.3
# 221      62.2      66.0  ...        28.6       17.6       38.4       68.2
# 222      67.6      71.1  ...        60.0       45.7       85.7       32.2
# 223      73.4      78.7  ...        75.6       57.8       99.3       23.2
# 224      77.7      83.1  ...        97.7       87.0      100.0        NaN
#
#      homocides  Internetuse        pov   literacy     lifeEx  \
# 0          9.8          8.3        NaN  34.357446  64.477000
# 1          2.2         62.4   0.500000  97.411140  78.448800
# 2          1.4         47.7   0.400000  81.407837  76.686600
# 3          7.2          NaN        NaN        NaN        NaN
# 4          0.0         91.6        NaN        NaN        NaN
# ..         ...          ...        ...        ...        ...
# 220        9.4         22.3  41.300000  63.569308  61.234800
# 221        7.3         14.1  46.512500  58.923505  63.368600
# 222        4.5         25.7  15.025000  73.815040  68.853723
# 223        6.7         58.8   2.566667  95.254961  75.694861
# 224        2.2         85.9   0.600000        NaN  80.679517
#
#                  country
# 0            Afghanistan
# 1                Albania
# 2                Algeria
# 3         American Samoa
# 4                Andorra
# ..                   ...
# 220   Sub-Saharan Africa
# 221           Low income
# 222  Lower middle income
# 223  Upper middle income
# 224          High income
#
# [225 rows x 30 columns]

# %%
df_country = df_merged.iloc[:213,:]
df_grouped = df_merged.iloc[213:,:] # seperate regions

# %%
#df_country.dtypes

# %%
#df_country.shape
#df_country.info

# %% [markdown]
# ## Missing values

# %%
percent_missing = df_country.isnull().sum() * 100 / len(df_country)
percent_missing
# Out:
# Population           1.408451
# pop_density          4.694836
# gni                 16.901408
# gni_pc              89.671362
# ppp_gni             22.535211
# ppp_gni.pc          99.530516
# gdp                  5.164319
# gdp_pc               5.164319
# lifeEx_m             7.042254
# lifeEx_f             7.042254
# married_by_18       52.112676
# mobile_money_m      32.863850
# mobile_money_f      32.863850
# employment_m        12.676056
# employment_f        12.676056
# firm_f_ownership    49.765258
# share_senior_f      53.051643
# parlia_w            10.798122
# fert                 6.103286
# br                  24.413146
# water_perc          39.906103
# sani_perc           41.314554
# elec_perc            0.469484
# slum_perc           55.868545
# homocides           20.657277
# Internetuse          5.164319
# pov                 28.638498
# literacy            30.516432
# lifeEx               6.103286
# country              0.000000
# dtype: float64

# %% [markdown]
# # @MYSELF: If you have time, replace missing values with nearest neighbor (replace by mean doesnt make much sens bc of the high variance of some itmes.

# %%
df_country.drop(['Population', 'gni', 'gni_pc', 'ppp_gni', 'ppp_gni.pc', 
        'gdp', 'sani_perc', 'slum_perc'], axis = 1, inplace = True)
# Out:
# /var/folders/np/_4nsf5195pl0jfyhg25kr9q80000gn/T/ipykernel_10252/1323334478.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_country.drop(['Population', 'gni', 'gni_pc', 'ppp_gni', 'ppp_gni.pc',

# %%
df_country
# Out:
#      pop_density  gdp_pc  lifeEx_m  lifeEx_f  married_by_18  mobile_money_m  \
# 0           57.0     1.5      63.7      66.7           28.3            22.5
# 1          105.0     2.7      77.2      80.3           11.8            42.0
# 2           18.0    -1.1      75.9      78.3            3.8            56.3
# 3          277.0     2.5       NaN       NaN            NaN             NaN
# 4          164.0     1.7       NaN       NaN            NaN             NaN
# ..           ...     ...       ...       ...            ...             ...
# 208        306.0    -1.5      76.6      83.2            NaN             NaN
# 209        759.0    -1.6      72.6      75.9           13.4            34.4
# 210         54.0    -0.2      64.5      67.9           31.9             NaN
# 211         23.0    -1.5      61.1      67.2           29.0            51.7
# 212         37.0    -9.4      60.0      63.2           33.7            59.2
#
#      mobile_money_f  employment_m  employment_f  firm_f_ownership  ...  \
# 0               7.2          20.3           8.2               2.2  ...
# 1              38.1          44.2          47.9              13.1  ...
# 2              29.3          66.4          74.5               NaN  ...
# 3               NaN           NaN           NaN               NaN  ...
# 4               NaN           NaN           NaN               NaN  ...
# ..              ...           ...           ...               ...  ...
# 208             NaN          93.4          93.4               NaN  ...
# 209            15.9          70.3          77.3              10.7  ...
# 210             NaN          45.4          38.4               6.6  ...
# 211            40.3          34.5          17.8              43.7  ...
# 212            51.7          42.4          20.4              42.5  ...
#
#          fert          br  water_perc  elec_perc  homocides  Internetuse  \
# 0    4.648857   42.300000        27.6       97.7        9.8          8.3
# 1    1.636571   98.400000        70.7       99.9        2.2         62.4
# 2    3.016429   99.600000        72.4       99.6        1.4         47.7
# 3         NaN         NaN        98.4        NaN        7.2          NaN
# 4         NaN  100.000000        90.6      100.0        0.0         91.6
# ..        ...         ...         ...        ...        ...          ...
# 208  2.072857         NaN        97.9      100.0       49.3         64.4
# 209  3.756571   98.133333        79.7       99.7        1.2         63.3
# 210  3.901000   23.900000         NaN       79.2        6.8         26.7
# 211  4.737714   12.700000         NaN       40.3        5.4          NaN
# 212  3.712429   40.625000        29.5       40.1        7.5         24.4
#
#       pov   literacy    lifeEx                country
# 0     NaN  34.357446  64.47700            Afghanistan
# 1     0.5  97.411140  78.44880                Albania
# 2     0.4  81.407837  76.68660                Algeria
# 3     NaN        NaN       NaN         American Samoa
# 4     NaN        NaN       NaN                Andorra
# ..    ...        ...       ...                    ...
# 208   NaN        NaN  79.50878  Virgin Islands (U.S.)
# 209   0.5  96.518783  73.89800     West Bank and Gaza
# 210  18.3        NaN  66.11500            Yemen, Rep.
# 211  58.7  86.747963  63.41940                 Zambia
# 212  31.6  86.138065  61.10580               Zimbabwe
#
# [213 rows x 22 columns]

# %% [markdown]
# - based on missing values above, choose gdp pc as economic proxy
# - Drop slum_perc due to high missing value and proxy for urbanization is not really needed
# - drop sanitation due to high number of missing values

# %% [markdown]
# ## Variable discription

# %% [markdown]
# -  pop_density = population denstity (latest availabe year)
# - gdp_pc = GDP per capita (latest availabe year)
# - lifeEx_m = Life expectancy at birth for male population (latest availabe year)
# - lifeEx_f = Life expectancy at birth for female population (latest availabe year)
# - married_by_18 = percentatge of female population bteween 18 and 24 married by the age of 18
# - mobile_money_m = percent of mobile money accounts held by men
# - mobile_money_f = percent of mobile money accounts held by women
# - ....@Me: I need to finish this list

# %% [markdown]
# ##  Describing the data (country dataframe only)

# %%
# Percentiles
df_country.describe(percentiles = [.25, .5, .75 ,.95])
# Out:
#        pop_density      gdp_pc    lifeEx_m    lifeEx_f  married_by_18  \
# count   203.000000  202.000000  198.000000  198.000000     102.000000
# mean    142.512315    1.262376   70.586364   75.461616      21.837255
# std     161.176226    3.443816    7.194461    7.613076      13.735053
# min       0.000000  -20.100000   51.500000   55.900000       0.000000
# 25%      34.500000   -0.175000   65.850000   70.125000      10.900000
# 50%      83.000000    1.400000   71.300000   77.250000      21.350000
# 75%     202.500000    3.175000   75.975000   80.900000      30.100000
# 95%     494.600000    5.490000   80.800000   85.115000      46.345000
# max     861.000000   16.400000   82.900000   88.000000      61.000000
#
#        mobile_money_m  mobile_money_f  employment_m  employment_f  \
# count      143.000000      143.000000    186.000000    186.000000
# mean        64.592308       57.695804     60.853226     59.672581
# std         25.124266       28.480134     23.663011     31.012206
# min         12.500000        4.700000      7.300000      1.000000
# 25%         45.600000       33.100000     44.225000     30.125000
# 50%         62.400000       53.900000     65.850000     67.050000
# 75%         87.600000       82.900000     80.475000     88.250000
# 95%         99.390000       99.200000     92.025000     95.425000
# max        100.000000      100.000000     99.600000     99.500000
#
#        firm_f_ownership  ...    parlia_w        fert          br  water_perc  \
# count        107.000000  ...  190.000000  200.000000  161.000000  128.000000
# mean          33.931776  ...   24.636842    2.681141   83.691925   73.953906
# std           15.989912  ...   12.955753    1.286418   24.118053   29.659259
# min            2.200000  ...    0.000000    1.057143    2.700000    5.600000
# 25%           22.850000  ...   15.000000    1.686071   73.900000   54.225000
# 50%           34.900000  ...   24.000000    2.210857   96.800000   88.950000
# 75%           43.600000  ...   34.000000    3.595107  100.000000   98.450000
# 95%           64.400000  ...   46.550000    5.116757  100.000000  100.000000
# max           70.400000  ...   61.000000    6.996286  100.000000  100.000000
#
#         elec_perc   homocides  Internetuse         pov    literacy      lifeEx
# count  212.000000  169.000000   202.000000  152.000000  148.000000  200.000000
# mean    85.162264    7.752663    54.784653   12.591095   83.418932   72.747695
# std     25.518520   12.960595    28.557085   19.408177   19.367797    7.547173
# min      4.200000    0.000000     1.300000    0.000000   24.157270   52.720000
# 25%     82.200000    1.200000    28.400000    0.438333   73.935326   67.639200
# 50%     99.900000    2.800000    59.400000    2.262500   92.974389   74.197037
# 75%    100.000000    8.200000    80.100000   18.800000   98.056773   78.218780
# 95%    100.000000   33.480000    96.375000   57.875000   99.785291   82.793488
# max    100.000000  105.200000    99.500000   78.800000   99.989775   84.861463
#
# [9 rows x 21 columns]

# %%
# Matplotlib

df_country.hist(figsize=(40,40), bins = 30, color = "blue")
# Out:
# array([[<AxesSubplot:title={'center':'pop_density'}>,
#         <AxesSubplot:title={'center':'gdp_pc'}>,
#         <AxesSubplot:title={'center':'lifeEx_m'}>,
#         <AxesSubplot:title={'center':'lifeEx_f'}>,
#         <AxesSubplot:title={'center':'married_by_18'}>],
#        [<AxesSubplot:title={'center':'mobile_money_m'}>,
#         <AxesSubplot:title={'center':'mobile_money_f'}>,
#         <AxesSubplot:title={'center':'employment_m'}>,
#         <AxesSubplot:title={'center':'employment_f'}>,
#         <AxesSubplot:title={'center':'firm_f_ownership'}>],
#        [<AxesSubplot:title={'center':'share_senior_f'}>,
#         <AxesSubplot:title={'center':'parlia_w'}>,
#         <AxesSubplot:title={'center':'fert'}>,
#         <AxesSubplot:title={'center':'br'}>,
#         <AxesSubplot:title={'center':'water_perc'}>],
#        [<AxesSubplot:title={'center':'elec_perc'}>,
#         <AxesSubplot:title={'center':'homocides'}>,
#         <AxesSubplot:title={'center':'Internetuse'}>,
#         <AxesSubplot:title={'center':'pov'}>,
#         <AxesSubplot:title={'center':'literacy'}>],
#        [<AxesSubplot:title={'center':'lifeEx'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# ## Create correlation plot

# %%
corr = df_country.corr() # parse df to correlation command
mask = np.zeros_like(corr) # mask all zeros 
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"): # hide mirroring part
    f, ax = plt.subplots(figsize=(12, 12)) # define plotsize
    ax = sns.heatmap(corr, mask=mask,cmap= 'viridis', vmin=-1,vmax=1,annot=True, square=True)

# %% [markdown]
# - as aspected we find high correlation among some variables. For gender disaggreagted variables life expectancy, mobile money and emplyment 95% or greater. Life exp can be replaced by total life expectancy variable
#
# -> Use idependent t-test (two sample two tailed) to see if m an f are significantly different
#
# @Nelson: Does that make sense?

# %%
mm = df_country[['mobile_money_m', 'mobile_money_f']]
mm.var()
mm.mean()
rp.ttest(group1= mm['mobile_money_m'], group1_name= "mobile_mon_m",
         group2= mm['mobile_money_f'], group2_name= "mobile_mon_m")

# mobile money access is different (p <0.05)
# Out:
# /opt/anaconda3/envs/DA/lib/python3.10/site-packages/researchpy/ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# (       Variable      N       Mean         SD        SE  95% Conf.   Interval
#  0  mobile_mon_m  143.0  64.592308  25.124266  2.100997  60.439034  68.745581
#  1  mobile_mon_m  143.0  57.695804  28.480134  2.381628  52.987775  62.403833
#  2      combined  286.0  61.144056  27.029153  1.598267  57.998150  64.289962,
#                              Independent t-test   results
#  0  Difference (mobile_mon_m - mobile_mon_m) =     6.8965
#  1                        Degrees of freedom =   284.0000
#  2                                         t =     2.1715
#  3                     Two side test p value =     0.0307
#  4                    Difference < 0 p value =     0.9846
#  5                    Difference > 0 p value =     0.0154
#  6                                 Cohen's d =     0.2568
#  7                                 Hedge's g =     0.2561
#  8                             Glass's delta =     0.2745
#  9                               Pearson's r =     0.1278)

# %%
le = df_country[['lifeEx_m', 'lifeEx_f']]
le.var()
le.mean()

rp.ttest(group1= le['lifeEx_m'], group1_name= "lifeEx_m",
         group2= le['lifeEx_f'], group2_name= "lifeEx_f")

# life expanctancy is significantly t (p <0.01) (women live longer)
# Out:
# /opt/anaconda3/envs/DA/lib/python3.10/site-packages/researchpy/ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# (   Variable      N       Mean        SD        SE  95% Conf.   Interval
#  0  lifeEx_m  198.0  70.586364  7.194461  0.511288  69.578063  71.594664
#  1  lifeEx_f  198.0  75.461616  7.613076  0.541038  74.394647  76.528585
#  2  combined  396.0  73.023990  7.789594  0.391442  72.254420  73.793560,
#                      Independent t-test   results
#  0  Difference (lifeEx_m - lifeEx_f) =    -4.8753
#  1                Degrees of freedom =   394.0000
#  2                                 t =    -6.5492
#  3             Two side test p value =     0.0000
#  4            Difference < 0 p value =     0.0000
#  5            Difference > 0 p value =     1.0000
#  6                         Cohen's d =    -0.6582
#  7                         Hedge's g =    -0.6570
#  8                     Glass's delta =    -0.6776
#  9                       Pearson's r =     0.3133)

# %%
emp = df_country[['employment_m', 'employment_f']]
emp.var()
emp.mean()

rp.ttest(group1= emp['employment_m'], group1_name= "employment_m",
         group2= emp['employment_f'], group2_name= "employment_f")

# emplyment is not different --> Change to gap
# Out:
# /opt/anaconda3/envs/DA/lib/python3.10/site-packages/researchpy/ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# (       Variable      N       Mean         SD        SE  95% Conf.   Interval
#  0  employment_m  186.0  60.853226  23.663011  1.735056  57.430186  64.276266
#  1  employment_f  186.0  59.672581  31.012206  2.273925  55.186422  64.158739
#  2      combined  372.0  60.262903  27.552606  1.428536  57.453860  63.071946,
#                              Independent t-test   results
#  0  Difference (employment_m - employment_f) =     1.1806
#  1                        Degrees of freedom =   370.0000
#  2                                         t =     0.4128
#  3                     Two side test p value =     0.6800
#  4                    Difference < 0 p value =     0.6600
#  5                    Difference > 0 p value =     0.3400
#  6                                 Cohen's d =     0.0428
#  7                                 Hedge's g =     0.0427
#  8                             Glass's delta =     0.0499
#  9                               Pearson's r =     0.0215)

# %%
# Create new variables and drop redundant ones

df_country['emp_gap'] = df_country['employment_m'] - df_country['employment_f']
df_country['mm_acc_gap'] = df_country['mobile_money_m'] - df_country['mobile_money_f']
# Out:
# /var/folders/np/_4nsf5195pl0jfyhg25kr9q80000gn/T/ipykernel_10252/4084824723.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_country['emp_gap'] = df_country['employment_m'] - df_country['employment_f']
# /var/folders/np/_4nsf5195pl0jfyhg25kr9q80000gn/T/ipykernel_10252/4084824723.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_country['mm_acc_gap'] = df_country['mobile_money_m'] - df_country['mobile_money_f']

# %%
df_country.drop(['mobile_money_m', 'mobile_money_f', 'employment_m', 'employment_f', 
                 'lifeEx_f', 'lifeEx_m'], axis = 1, inplace = True)
# Out:
# /var/folders/np/_4nsf5195pl0jfyhg25kr9q80000gn/T/ipykernel_10252/1713288554.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_country.drop(['mobile_money_m', 'mobile_money_f', 'employment_m', 'employment_f',

# %%
df_country
# Out:
#      pop_density  gdp_pc  married_by_18  firm_f_ownership  share_senior_f  \
# 0           57.0     1.5           28.3               2.2             4.3
# 1          105.0     2.7           11.8              13.1            22.6
# 2           18.0    -1.1            3.8               NaN             NaN
# 3          277.0     2.5            NaN               NaN             NaN
# 4          164.0     1.7            NaN               NaN             NaN
# ..           ...     ...            ...               ...             ...
# 208        306.0    -1.5            NaN               NaN             NaN
# 209        759.0    -1.6           13.4              10.7            15.5
# 210         54.0    -0.2           31.9               6.6             4.5
# 211         23.0    -1.5           29.0              43.7            28.5
# 212         37.0    -9.4           33.7              42.5            22.8
#
#      parlia_w      fert          br  water_perc  elec_perc  homocides  \
# 0        27.0  4.648857   42.300000        27.6       97.7        9.8
# 1        36.0  1.636571   98.400000        70.7       99.9        2.2
# 2         8.0  3.016429   99.600000        72.4       99.6        1.4
# 3         NaN       NaN         NaN        98.4        NaN        7.2
# 4        46.0       NaN  100.000000        90.6      100.0        0.0
# ..        ...       ...         ...         ...        ...        ...
# 208       NaN  2.072857         NaN        97.9      100.0       49.3
# 209       NaN  3.756571   98.133333        79.7       99.7        1.2
# 210       0.0  3.901000   23.900000         NaN       79.2        6.8
# 211      15.0  4.737714   12.700000         NaN       40.3        5.4
# 212      32.0  3.712429   40.625000        29.5       40.1        7.5
#
#      Internetuse   pov   literacy    lifeEx                country  emp_gap  \
# 0            8.3   NaN  34.357446  64.47700            Afghanistan     12.1
# 1           62.4   0.5  97.411140  78.44880                Albania     -3.7
# 2           47.7   0.4  81.407837  76.68660                Algeria     -8.1
# 3            NaN   NaN        NaN       NaN         American Samoa      NaN
# 4           91.6   NaN        NaN       NaN                Andorra      NaN
# ..           ...   ...        ...       ...                    ...      ...
# 208         64.4   NaN        NaN  79.50878  Virgin Islands (U.S.)      0.0
# 209         63.3   0.5  96.518783  73.89800     West Bank and Gaza     -7.0
# 210         26.7  18.3        NaN  66.11500            Yemen, Rep.      7.0
# 211          NaN  58.7  86.747963  63.41940                 Zambia     16.7
# 212         24.4  31.6  86.138065  61.10580               Zimbabwe     22.0
#
#      mm_acc_gap
# 0          15.3
# 1           3.9
# 2          27.0
# 3           NaN
# 4           NaN
# ..          ...
# 208         NaN
# 209        18.5
# 210         NaN
# 211        11.4
# 212         7.5
#
# [213 rows x 18 columns]

# %%
df_country.columns
df_country.info
# Out:
# <bound method DataFrame.info of      pop_density  gdp_pc  married_by_18  firm_f_ownership  share_senior_f  \
# 0           57.0     1.5           28.3               2.2             4.3
# 1          105.0     2.7           11.8              13.1            22.6
# 2           18.0    -1.1            3.8               NaN             NaN
# 3          277.0     2.5            NaN               NaN             NaN
# 4          164.0     1.7            NaN               NaN             NaN
# ..           ...     ...            ...               ...             ...
# 208        306.0    -1.5            NaN               NaN             NaN
# 209        759.0    -1.6           13.4              10.7            15.5
# 210         54.0    -0.2           31.9               6.6             4.5
# 211         23.0    -1.5           29.0              43.7            28.5
# 212         37.0    -9.4           33.7              42.5            22.8
#
#      parlia_w      fert          br  water_perc  elec_perc  homocides  \
# 0        27.0  4.648857   42.300000        27.6       97.7        9.8
# 1        36.0  1.636571   98.400000        70.7       99.9        2.2
# 2         8.0  3.016429   99.600000        72.4       99.6        1.4
# 3         NaN       NaN         NaN        98.4        NaN        7.2
# 4        46.0       NaN  100.000000        90.6      100.0        0.0
# ..        ...       ...         ...         ...        ...        ...
# 208       NaN  2.072857         NaN        97.9      100.0       49.3
# 209       NaN  3.756571   98.133333        79.7       99.7        1.2
# 210       0.0  3.901000   23.900000         NaN       79.2        6.8
# 211      15.0  4.737714   12.700000         NaN       40.3        5.4
# 212      32.0  3.712429   40.625000        29.5       40.1        7.5
#
#      Internetuse   pov   literacy    lifeEx                country  emp_gap  \
# 0            8.3   NaN  34.357446  64.47700            Afghanistan     12.1
# 1           62.4   0.5  97.411140  78.44880                Albania     -3.7
# 2           47.7   0.4  81.407837  76.68660                Algeria     -8.1
# 3            NaN   NaN        NaN       NaN         American Samoa      NaN
# 4           91.6   NaN        NaN       NaN                Andorra      NaN
# ..           ...   ...        ...       ...                    ...      ...
# 208         64.4   NaN        NaN  79.50878  Virgin Islands (U.S.)      0.0
# 209         63.3   0.5  96.518783  73.89800     West Bank and Gaza     -7.0
# 210         26.7  18.3        NaN  66.11500            Yemen, Rep.      7.0
# 211          NaN  58.7  86.747963  63.41940                 Zambia     16.7
# 212         24.4  31.6  86.138065  61.10580               Zimbabwe     22.0
#
#      mm_acc_gap
# 0          15.3
# 1           3.9
# 2          27.0
# 3           NaN
# 4           NaN
# ..          ...
# 208         NaN
# 209        18.5
# 210         NaN
# 211        11.4
# 212         7.5
#
# [213 rows x 18 columns]>

# %%
### outfile 
df_country.to_csv('220516_compiled_data.csv')

# %%
df = df_country

# %%
df = pd.read_csv('220516_compiled_data.csv') ## compiled df, used from 4. onwards

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# pop_density         float64
# gdp_pc              float64
# married_by_18       float64
# firm_f_ownership    float64
# share_senior_f      float64
# parlia_w            float64
# fert                float64
# br                  float64
# water_perc          float64
# elec_perc           float64
# homocides           float64
# Internetuse         float64
# pov                 float64
# literacy            float64
# lifeEx              float64
# country              object
# emp_gap             float64
# mm_acc_gap          float64
# dtype: object

# %%
#@ Nelson: How can I implement a better nan replacement? Mean and median arent great becuase varaiance is
# is so high. 
# What imputation do you suggest?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [50], in <cell line: 6>()
#       6 for i, frac in enumerate(fraction):
#       7     for j in range(n_repeat):
# ----> 8         X, true_labels, Xm = df(fraction_missing=frac, n_clusters=5)
#       9         labels, centroids, X_hat = kmeans_missing(Xm, n_clusters=5)
#      10         any_missing = np.any(~np.isfinite(Xm), 1)
#
# TypeError: 'DataFrame' object is not callable

# %%
df = df.fillna(df.median()) # impute missing values with medain
# Out:
# /var/folders/np/_4nsf5195pl0jfyhg25kr9q80000gn/T/ipykernel_16894/670022785.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df = df.fillna(df.median()) # impute missing values with medain

# %% [markdown]
# ### Create new correlation plot

# %%
corr = df.corr() # parse df to correlation command
mask = np.zeros_like(corr) # mask all zeros 
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"): # hide mirroring part
    f, ax = plt.subplots(figsize=(12, 12)) # define plotsize
    ax = sns.heatmap(corr, mask=mask,cmap= 'viridis', vmin=-1,vmax=1,annot=True, square=True)

# %% [markdown]
# - Fertility rate, women married under 18 and poverty are highly correlated

# %%
df
# Out:
#      Unnamed: 0  pop_density  gdp_pc  married_by_18  firm_f_ownership  \
# 0             0         57.0     1.5          28.30               2.2
# 1             1        105.0     2.7          11.80              13.1
# 2             2         18.0    -1.1           3.80              34.9
# 3             3        277.0     2.5          21.35              34.9
# 4             4        164.0     1.7          21.35              34.9
# ..          ...          ...     ...            ...               ...
# 208         208        306.0    -1.5          21.35              34.9
# 209         209        759.0    -1.6          13.40              10.7
# 210         210         54.0    -0.2          31.90               6.6
# 211         211         23.0    -1.5          29.00              43.7
# 212         212         37.0    -9.4          33.70              42.5
#
#      share_senior_f  parlia_w      fert          br  water_perc  elec_perc  \
# 0               4.3      27.0  4.648857   42.300000       27.60       97.7
# 1              22.6      36.0  1.636571   98.400000       70.70       99.9
# 2              30.3       8.0  3.016429   99.600000       72.40       99.6
# 3              30.3      24.0  2.210857   96.800000       98.40       99.9
# 4              30.3      46.0  2.210857  100.000000       90.60      100.0
# ..              ...       ...       ...         ...         ...        ...
# 208            30.3      24.0  2.072857   96.800000       97.90      100.0
# 209            15.5      24.0  3.756571   98.133333       79.70       99.7
# 210             4.5       0.0  3.901000   23.900000       88.95       79.2
# 211            28.5      15.0  4.737714   12.700000       88.95       40.3
# 212            22.8      32.0  3.712429   40.625000       29.50       40.1
#
#      homocides  Internetuse      pov   literacy     lifeEx  \
# 0          9.8          8.3   2.2625  34.357446  64.477000
# 1          2.2         62.4   0.5000  97.411140  78.448800
# 2          1.4         47.7   0.4000  81.407837  76.686600
# 3          7.2         59.4   2.2625  92.974389  74.197037
# 4          0.0         91.6   2.2625  92.974389  74.197037
# ..         ...          ...      ...        ...        ...
# 208       49.3         64.4   2.2625  92.974389  79.508780
# 209        1.2         63.3   0.5000  96.518783  73.898000
# 210        6.8         26.7  18.3000  92.974389  66.115000
# 211        5.4         59.4  58.7000  86.747963  63.419400
# 212        7.5         24.4  31.6000  86.138065  61.105800
#
#                    country  emp_gap  mm_acc_gap
# 0              Afghanistan     12.1        15.3
# 1                  Albania     -3.7         3.9
# 2                  Algeria     -8.1        27.0
# 3           American Samoa      0.0         5.7
# 4                  Andorra      0.0         5.7
# ..                     ...      ...         ...
# 208  Virgin Islands (U.S.)      0.0         5.7
# 209     West Bank and Gaza     -7.0        18.5
# 210            Yemen, Rep.      7.0         5.7
# 211                 Zambia     16.7        11.4
# 212               Zimbabwe     22.0         7.5
#
# [213 rows x 19 columns]

# %%
#@ Myself: if you have time, check for contribution

# %% [markdown]
# #  Standarizing the data

# %% [markdown]
# - use standard scaler to force all (expet country) on the same scale

# %%
country = df['country'] # Seperate country to be able to change type

# %%
#df
# Out:
#      Unnamed: 0  pop_density  gdp_pc  married_by_18  firm_f_ownership  \
# 0             0         57.0     1.5           28.3               2.2
# 1             1        105.0     2.7           11.8              13.1
# 2             2         18.0    -1.1            3.8               NaN
# 3             3        277.0     2.5            NaN               NaN
# 4             4        164.0     1.7            NaN               NaN
# ..          ...          ...     ...            ...               ...
# 208         208        306.0    -1.5            NaN               NaN
# 209         209        759.0    -1.6           13.4              10.7
# 210         210         54.0    -0.2           31.9               6.6
# 211         211         23.0    -1.5           29.0              43.7
# 212         212         37.0    -9.4           33.7              42.5
#
#      share_senior_f  parlia_w      fert          br  water_perc  elec_perc  \
# 0               4.3      27.0  4.648857   42.300000        27.6       97.7
# 1              22.6      36.0  1.636571   98.400000        70.7       99.9
# 2               NaN       8.0  3.016429   99.600000        72.4       99.6
# 3               NaN       NaN       NaN         NaN        98.4        NaN
# 4               NaN      46.0       NaN  100.000000        90.6      100.0
# ..              ...       ...       ...         ...         ...        ...
# 208             NaN       NaN  2.072857         NaN        97.9      100.0
# 209            15.5       NaN  3.756571   98.133333        79.7       99.7
# 210             4.5       0.0  3.901000   23.900000         NaN       79.2
# 211            28.5      15.0  4.737714   12.700000         NaN       40.3
# 212            22.8      32.0  3.712429   40.625000        29.5       40.1
#
#      homocides  Internetuse   pov   literacy    lifeEx                country  \
# 0          9.8          8.3   NaN  34.357446  64.47700            Afghanistan
# 1          2.2         62.4   0.5  97.411140  78.44880                Albania
# 2          1.4         47.7   0.4  81.407837  76.68660                Algeria
# 3          7.2          NaN   NaN        NaN       NaN         American Samoa
# 4          0.0         91.6   NaN        NaN       NaN                Andorra
# ..         ...          ...   ...        ...       ...                    ...
# 208       49.3         64.4   NaN        NaN  79.50878  Virgin Islands (U.S.)
# 209        1.2         63.3   0.5  96.518783  73.89800     West Bank and Gaza
# 210        6.8         26.7  18.3        NaN  66.11500            Yemen, Rep.
# 211        5.4          NaN  58.7  86.747963  63.41940                 Zambia
# 212        7.5         24.4  31.6  86.138065  61.10580               Zimbabwe
#
#      emp_gap  mm_acc_gap
# 0       12.1        15.3
# 1       -3.7         3.9
# 2       -8.1        27.0
# 3        NaN         NaN
# 4        NaN         NaN
# ..       ...         ...
# 208      0.0         NaN
# 209     -7.0        18.5
# 210      7.0         NaN
# 211     16.7        11.4
# 212     22.0         7.5
#
# [213 rows x 19 columns]

# %%
df = df.drop(['country'], axis =1)

# %%
columns = df.columns # get cols to mege them to df later again

# %%
df
# Out:
#      Unnamed: 0  pop_density  gdp_pc  married_by_18  firm_f_ownership  \
# 0             0         57.0     1.5          28.30               2.2
# 1             1        105.0     2.7          11.80              13.1
# 2             2         18.0    -1.1           3.80              34.9
# 3             3        277.0     2.5          21.35              34.9
# 4             4        164.0     1.7          21.35              34.9
# ..          ...          ...     ...            ...               ...
# 208         208        306.0    -1.5          21.35              34.9
# 209         209        759.0    -1.6          13.40              10.7
# 210         210         54.0    -0.2          31.90               6.6
# 211         211         23.0    -1.5          29.00              43.7
# 212         212         37.0    -9.4          33.70              42.5
#
#      share_senior_f  parlia_w      fert          br  water_perc  elec_perc  \
# 0               4.3      27.0  4.648857   42.300000       27.60       97.7
# 1              22.6      36.0  1.636571   98.400000       70.70       99.9
# 2              30.3       8.0  3.016429   99.600000       72.40       99.6
# 3              30.3      24.0  2.210857   96.800000       98.40       99.9
# 4              30.3      46.0  2.210857  100.000000       90.60      100.0
# ..              ...       ...       ...         ...         ...        ...
# 208            30.3      24.0  2.072857   96.800000       97.90      100.0
# 209            15.5      24.0  3.756571   98.133333       79.70       99.7
# 210             4.5       0.0  3.901000   23.900000       88.95       79.2
# 211            28.5      15.0  4.737714   12.700000       88.95       40.3
# 212            22.8      32.0  3.712429   40.625000       29.50       40.1
#
#      homocides  Internetuse      pov   literacy     lifeEx  emp_gap  \
# 0          9.8          8.3   2.2625  34.357446  64.477000     12.1
# 1          2.2         62.4   0.5000  97.411140  78.448800     -3.7
# 2          1.4         47.7   0.4000  81.407837  76.686600     -8.1
# 3          7.2         59.4   2.2625  92.974389  74.197037      0.0
# 4          0.0         91.6   2.2625  92.974389  74.197037      0.0
# ..         ...          ...      ...        ...        ...      ...
# 208       49.3         64.4   2.2625  92.974389  79.508780      0.0
# 209        1.2         63.3   0.5000  96.518783  73.898000     -7.0
# 210        6.8         26.7  18.3000  92.974389  66.115000      7.0
# 211        5.4         59.4  58.7000  86.747963  63.419400     16.7
# 212        7.5         24.4  31.6000  86.138065  61.105800     22.0
#
#      mm_acc_gap
# 0          15.3
# 1           3.9
# 2          27.0
# 3           5.7
# 4           5.7
# ..          ...
# 208         5.7
# 209        18.5
# 210         5.7
# 211        11.4
# 212         7.5
#
# [213 rows x 18 columns]

# %%
scaler = StandardScaler()

# %%
df_rescaled = scaler.fit_transform(df)
df_rescaled
# Out:
# array([[-1.72393811, -0.52531823,  0.06890261, ..., -1.14459161,
#          1.07925142,  1.36198572],
#        [-1.70767455, -0.22048517,  0.42758912, ...,  0.76852152,
#         -0.46128076, -0.40306403],
#        [-1.69141098, -0.77299508, -0.70825149, ...,  0.5272292 ,
#         -0.89028973,  3.17348414],
#        ...,
#        [ 1.69141098, -0.54437029, -0.43923661, ..., -0.9203056 ,
#          0.58199103, -0.12437197],
#        [ 1.70767455, -0.74124164, -0.82781366, ..., -1.28940534,
#          1.52776079,  0.75815291],
#        [ 1.72393811, -0.652332  , -3.1891665 , ..., -1.60619906,
#          2.04452158,  0.1543201 ]])

# %% [markdown]
# ### get df with cols and standartized values back

# %%
df_rescaled = pd.DataFrame(data= df_rescaled, columns = columns)
df_rescaled
# Out:
#      Unnamed: 0  pop_density    gdp_pc  married_by_18  firm_f_ownership  \
# 0     -1.723938    -0.525318  0.068903       0.709919         -2.853190
# 1     -1.707675    -0.220485  0.427589      -1.034051         -1.887767
# 2     -1.691411    -0.772995 -0.708251      -1.879612          0.043080
# 3     -1.675147     0.871833  0.367808      -0.024662          0.043080
# 4     -1.658884     0.154205  0.128684      -0.024662          0.043080
# ..          ...          ...       ...            ...               ...
# 208    1.658884     1.056003 -0.827814      -0.024662          0.043080
# 209    1.675147     3.932865 -0.857704      -0.864939         -2.100337
# 210    1.691411    -0.544370 -0.439237       1.090422         -2.463478
# 211    1.707675    -0.741242 -0.827814       0.783906          0.822504
# 212    1.723938    -0.652332 -3.189166       1.280673          0.716219
#
#      share_senior_f  parlia_w      fert        br  water_perc  elec_perc  \
# 0         -3.726370  0.199246  1.599043 -2.059838   -2.176178   0.490532
# 1         -1.071993  0.936610 -0.813664  0.531588   -0.384119   0.577084
# 2          0.044876 -1.357411  0.291540  0.587019   -0.313434   0.565281
# 3          0.044876 -0.046542 -0.353687  0.457679    0.767623   0.577084
# 4          0.044876  1.755903 -0.353687  0.605497    0.443306   0.581018
# ..              ...       ...       ...       ...         ...        ...
# 208        0.044876 -0.046542 -0.464218  0.457679    0.746833   0.581018
# 209       -2.101833 -0.046542  0.884362  0.519270   -0.009907   0.569215
# 210       -3.697360 -2.012845  1.000042 -2.909788    0.374700  -0.237287
# 211       -0.216210 -0.783906  1.670213 -3.427150    0.374700  -1.767674
# 212       -1.042983  0.608892  0.849005 -2.137211   -2.097178  -1.775542
#
#      homocides  Internetuse       pov  literacy    lifeEx   emp_gap  \
# 0     0.262795    -1.683118 -0.433690 -3.116055 -1.144592  1.079251
# 1    -0.387683     0.265744 -0.537396  0.664021  0.768522 -0.461281
# 2    -0.456154    -0.263799 -0.543280 -0.295379  0.527229 -0.890290
# 3     0.040263     0.157674 -0.433690  0.398037  0.186341 -0.100523
# 4    -0.575979     1.317625 -0.433690  0.398037  0.186341 -0.100523
# ..         ...          ...       ...       ...       ...       ...
# 208   3.643569     0.337790 -0.433690  0.398037  0.913661 -0.100523
# 209  -0.473272     0.298165 -0.537396  0.610524  0.145395 -0.783037
# 210   0.006027    -1.020289  0.509960  0.398037 -0.920306  0.581991
# 211  -0.113797     0.157674  2.887104  0.024762 -1.289405  1.527761
# 212   0.065940    -1.103142  1.292535 -0.011801 -1.606199  2.044522
#
#      mm_acc_gap
# 0      1.361986
# 1     -0.403064
# 2      3.173484
# 3     -0.124372
# 4     -0.124372
# ..          ...
# 208   -0.124372
# 209    1.857438
# 210   -0.124372
# 211    0.758153
# 212    0.154320
#
# [213 rows x 18 columns]

# %% [markdown]
# # K means clustering

# %% [markdown]
# ## Find number of clusters

# %%
sse = []  # Sum of sqt err
for i in range(1, 11):
    km = KMeans(
        n_clusters=i, init='random',
        n_init=10, max_iter=300,
        tol=1e-04, random_state=0
    )
    km.fit(df_rescaled)
    sse.append(km.inertia_)

# %%
## find the wlbow
plt.plot(range(1, 11), sse, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('SSE')
plt.show()

# %% [markdown]
# - Elbow is not super clear could be 3 or 8

# %%
## apply silouette 

score = silhouette_score(df_rescaled, km.labels_, metric='euclidean')
print('Silhouette Score: %.3f' % score)
# Out:
# Silhouette Score: 0.113

# %%
fig,ax = plt.subplots(2,2, figsize = (15,8))
for i in [2,3,4,5]:

    # create kmeans instance for different numbers of clusters
    km = KMeans(n_clusters=i, init= 'random', n_init =10, max_iter = 300, random_state = 0)
    q, mod = divmod(i,2)
    
    #create sioluette 
    visualizer = SilhouetteVisualizer(km, colors = 'yellowbrick', ax=ax[q-1][mod])
    visualizer.fit(df_rescaled)

# %%
##innitiate model

km = KMeans(n_clusters = [number here], init = 'random',
           n_init = 10, # number of iteration with seeds (default)
           max_iter = 300,  # max iteration (default)
           random_state = 0,
           tol = 1e-4 )

# %% [markdown]
# - oops --> no good solution

# %%
## Apply model to scaled data set

pred_cluster = km.fit_predict(df_rescaled) # fit_predict 
pred_cluster
# Out:
# array([1, 2, 0, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 4, 0, 1, 2, 2, 2, 4, 1, 2,
#        3, 2, 2, 3, 4, 2, 2, 1, 1, 3, 1, 2, 2, 2, 1, 1, 2, 2, 2, 2, 2, 4,
#        3, 1, 1, 2, 1, 2, 2, 2, 2, 2, 2, 3, 2, 4, 3, 0, 4, 3, 3, 2, 3, 1,
#        2, 3, 2, 2, 2, 3, 1, 2, 2, 3, 2, 2, 2, 2, 3, 1, 1, 4, 3, 4, 2, 2,
#        0, 3, 0, 0, 2, 2, 2, 2, 4, 2, 0, 2, 3, 3, 2, 0, 0, 2, 3, 2, 0, 3,
#        1, 0, 2, 2, 2, 1, 1, 2, 0, 1, 2, 0, 1, 2, 2, 0, 2, 2, 3, 2, 0, 1,
#        3, 3, 3, 2, 2, 2, 3, 1, 1, 2, 0, 2, 0, 1, 0, 2, 3, 3, 3, 3, 2, 2,
#        4, 0, 2, 2, 3, 3, 2, 3, 0, 1, 2, 2, 1, 2, 0, 2, 2, 3, 1, 4, 1, 2,
#        0, 4, 4, 4, 4, 1, 2, 2, 2, 0, 3, 1, 2, 3, 1, 3, 4, 0, 0, 3, 2, 4,
#        1, 2, 0, 2, 2, 2, 2, 3, 4, 2, 4, 0, 1, 1, 1], dtype=int32)

# %% [markdown]
# # run PCA (expolorartory)

# %%
###maybe reduction of dimesnions is useful to compare with clusters?

# %%
pca = PCA()
pca.fit(df_rescaled)

pca_rescaled = pca.transform(df_rescaled)

# %% [markdown]
# perc_var = np.round(pca.explained_variance_ratio_*100, decimals =1)
# labels = ['PC' + str(x) for x in range (1, len(perc_var)+1)]

# %%
## PCA plot


pca_rescaled = pd.DataFrame(pca_rescaled, columns = labels)
plt.scatter(pca_rescaled.PC1, pca_rescaled.PC2)
plt.title('PCA')
plt.xlabel('PC1 - {0}%'.format(per_var[0]))
plt.ylabel('PC2 - {0}%'.format(per_var[1]))
# Out:
# Text(0, 0.5, 'PC2 - 8.6%')

# %% [markdown]
# -- All over the show.Need to change vars
