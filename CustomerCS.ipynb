# %%
## Case Study Chrisso

# Set up
import numpy as np
import pandas as pd

# %%
# input data 

file1 = pd.read_csv('/Users/solveiggleser/Library/CloudStorage/OneDrive-Personal/Ironhack/GitHub/IronSolveig/Customer_Analysis_Case_Study/Data/file1.csv')
file2 = pd.read_csv('/Users/solveiggleser/Library/CloudStorage/OneDrive-Personal/Ironhack/GitHub/IronSolveig/Customer_Analysis_Case_Study/Data/file2.csv')
file3 = pd.read_csv('/Users/solveiggleser/Library/CloudStorage/OneDrive-Personal/Ironhack/GitHub/IronSolveig/Customer_Analysis_Case_Study/Data/file3.csv') 
file4 = pd.read_csv('/Users/solveiggleser/Library/CloudStorage/OneDrive-Personal/Ironhack/GitHub/IronSolveig/Customer_Analysis_Case_Study/Data/Data_Marketing_Customer_Analysis_Round2.csv')


#file_list = [file1, file2, file3, file4]

# %%
list(map(lambda x: x.columns, file_list))
list(map(len, list(map(lambda x: x.columns, file_list)) ))
# Out:
# [11, 11, 11, 26]

# %%
#Define to lower
def lower_case_column_names(file_list):
    file_list.columns=[i.lower() for i in file_list.columns]
    return file_list

# %%
# Apply to_lower

list(map(lower_case_column_names,file_list ))
# Out:
# [     customer       state gender             education  \
#  0     RB50392  Washington    NaN                Master
#  1     QZ44356     Arizona      F              Bachelor
#  2     AI49188      Nevada      F              Bachelor
#  3     WW63253  California      M              Bachelor
#  4     GA49547  Washington      M  High School or Below
#  ...       ...         ...    ...                   ...
#  4003      NaN         NaN    NaN                   NaN
#  4004      NaN         NaN    NaN                   NaN
#  4005      NaN         NaN    NaN                   NaN
#  4006      NaN         NaN    NaN                   NaN
#  4007      NaN         NaN    NaN                   NaN
#
#       customer lifetime value   income  monthly premium auto  \
#  0                        NaN      0.0                1000.0
#  1                 697953.59%      0.0                  94.0
#  2                1288743.17%  48767.0                 108.0
# ...

# %%
# define rename 

def rename_columns(file_list):
    file_list.rename(columns={'st':'state'}, inplace=True )
    return file_list

# apply rename 
list(map(rename_columns, file_list))
# Out:
# [     customer       state gender             education  \
#  0     RB50392  Washington    NaN                Master
#  1     QZ44356     Arizona      F              Bachelor
#  2     AI49188      Nevada      F              Bachelor
#  3     WW63253  California      M              Bachelor
#  4     GA49547  Washington      M  High School or Below
#  ...       ...         ...    ...                   ...
#  4003      NaN         NaN    NaN                   NaN
#  4004      NaN         NaN    NaN                   NaN
#  4005      NaN         NaN    NaN                   NaN
#  4006      NaN         NaN    NaN                   NaN
#  4007      NaN         NaN    NaN                   NaN
#
#       customer lifetime value   income  monthly premium auto  \
#  0                        NaN      0.0                1000.0
#  1                 697953.59%      0.0                  94.0
#  2                1288743.17%  48767.0                 108.0
# ...

# %%
## define drop

def drop_columns(file_list) :
    file_list.drop(columns=['customer'], inplace=True)
    return file_list

# apply drop

list(map(drop_columns, file_list))
# Out:
# [           state gender             education customer lifetime value  \
#  0     Washington    NaN                Master                     NaN
#  1        Arizona      F              Bachelor              697953.59%
#  2         Nevada      F              Bachelor             1288743.17%
#  3     California      M              Bachelor              764586.18%
#  4     Washington      M  High School or Below              536307.65%
#  ...          ...    ...                   ...                     ...
#  4003         NaN    NaN                   NaN                     NaN
#  4004         NaN    NaN                   NaN                     NaN
#  4005         NaN    NaN                   NaN                     NaN
#  4006         NaN    NaN                   NaN                     NaN
#  4007         NaN    NaN                   NaN                     NaN
#
#         income  monthly premium auto number of open complaints     policy type  \
# ...

# %%
# concat 

files_all = pd.concat(file_list, axis=0)

files_all
# Out:
#             state gender             education customer lifetime value  \
# 0      Washington    NaN                Master                     NaN
# 1         Arizona      F              Bachelor              697953.59%
# 2          Nevada      F              Bachelor             1288743.17%
# 3      California      M              Bachelor              764586.18%
# 4      Washington      M  High School or Below              536307.65%
# ...           ...    ...                   ...                     ...
# 10905      Nevada      F              Bachelor             15563.36944
# 10906      Oregon      F               College             5259.444853
# 10907     Arizona      F              Bachelor              23893.3041
# 10908  California      F               College             11971.97765
# 10909         NaN      M              Bachelor             6857.519928
#
#         income  monthly premium auto number of open complaints  \
# ...

# %%
# data type 

#files_all.describe
files_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22984 entries, 0 to 10909
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   state                          19416 non-null  object
#  1   gender                         19925 non-null  object
#  2   education                      20047 non-null  object
#  3   customer lifetime value        20040 non-null  object
#  4   income                         20047 non-null  float64
#  5   monthly premium auto           20047 non-null  float64
#  6   number of open complaints      19414 non-null  object
#  7   policy type                    20047 non-null  object
#  8   vehicle class                  19425 non-null  object
#  9   total claim amount             20047 non-null  float64
#  10  unnamed: 0                     10910 non-null  float64
#  11  response                       10279 non-null  object
# ...

# %%
## remove % 'customer lifetime value'

files_all['customer lifetime value'] = files_all['customer lifetime value'].str.replace('%', "")

#change to numeric 

files_all['customer lifetime value'] =  pd.to_numeric(files_all['customer lifetime value'])
#files_all.info() # check
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22984 entries, 0 to 10909
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   state                          19416 non-null  object
#  1   gender                         19925 non-null  object
#  2   education                      20047 non-null  object
#  3   customer lifetime value        2060 non-null   float64
#  4   income                         20047 non-null  float64
#  5   monthly premium auto           20047 non-null  float64
#  6   number of open complaints      19414 non-null  object
#  7   policy type                    20047 non-null  object
#  8   vehicle class                  19425 non-null  object
#  9   total claim amount             20047 non-null  float64
#  10  unnamed: 0                     10910 non-null  float64
#  11  response                       10279 non-null  object
# ...

# %%
print(files_all['number of open complaints'])
# Out:
# 0        1/0/00
# 1        1/0/00
# 2        1/0/00
# 3        1/0/00
# 4        1/0/00
#           ...
# 10905       NaN
# 10906       0.0
# 10907       0.0
# 10908       4.0
# 10909       0.0
# Name: number of open complaints, Length: 22984, dtype: object

# %%
# Replace with regex


#files_all['number of open complaints'] = files_all['number of open complaints'].str.replace(r'\D+', '', regex=True).astype('int')
#print(files_all)

# %%
## remove dublicates 

files_all.drop_duplicates(subset=['customer lifetime value', 'income', 'total claim amount' ], keep='first', inplace=True)

# %%
files_all.info
# Out:
# <bound method DataFrame.info of             state gender             education  customer lifetime value  \
# 0      Washington    NaN                Master                      NaN
# 1         Arizona      F              Bachelor                697953.59
# 2          Nevada      F              Bachelor               1288743.17
# 3      California      M              Bachelor                764586.18
# 4      Washington      M  High School or Below                536307.65
# ...           ...    ...                   ...                      ...
# 10882     Arizona      F              Bachelor                      NaN
# 10895  California      F              Bachelor                      NaN
# 10896      Oregon      F  High School or Below                      NaN
# 10901  Washington      M              Bachelor                      NaN
# 10903     Arizona      M               College                      NaN
#
#         income  monthly premium auto number of open complaints  \
# ...

# %%
## Replacing null values – Replace missing values with means of the column (for numerical columns)
